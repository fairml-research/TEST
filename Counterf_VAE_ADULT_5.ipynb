# %% [markdown]
# <a href="https://colab.research.google.com/github/fairml-research/TEST/blob/main/Counterf_VAE_ADULT_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
np.random.seed(7)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", palette="muted", color_codes=True, context="talk")
from IPython import display
# %matplotlib inline
import sys 
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.utils.class_weight import compute_class_weight

import keras as ke
import keras.backend as K
from keras.layers import Input, Dense, Dropout
from keras.models import Model

def load_ICU_data(path):
    column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 
                    'marital_status', 'occupation', 'relationship', 'race', 'sex', 
                    'capital_gain', 'capital_loss', 'hours_per_week', 'country', 'target']
    input_data = (pd.read_csv(path, names=column_names, 
                              na_values="?", sep=r'\s*,\s*', engine='python'))
                  #.loc[lambda df: df['race'].isin(['White', 'Black'])])
    input_data = pd.concat([input_data, pd.read_csv('http://grarivincent.com/old/adult.test', names=column_names, na_values="?", sep=r'\s*,\s*', engine='python').loc[1:,:] ])

    input_data[['age','fnlwgt','education_num','capital_gain', 'capital_loss', 'hours_per_week']] = input_data[['age','fnlwgt','education_num','capital_gain', 'capital_loss', 'hours_per_week']].astype(int)
    
    # sensitive attributes; we identify 'race' and 'sex' as sensitive attributes
    sensitive_attribs = ['sex']
    Z = (input_data.loc[:, sensitive_attribs]
         .assign(sex=lambda df: (df['sex'] == 'Male').astype(int)))
    # targets; 1 when someone makes over 50k , otherwise 0
    y = input_data['target'].replace({'<=50K.': 0, '>50K.': 1, '>50K': 1, '<=50K': 0 })
    XNC = input_data.loc[:, ['race','age','country']]
    XNC = XNC.assign(race=lambda df: (df['race'] == 'White').astype(int))
    print(XNC.shape)
    XNC = (XNC
           .fillna('Unknown')
           .pipe(pd.get_dummies, columns = ['country'], drop_first=True))
    # features; note that the 'target' and sentive attribute columns are dropped
    X = (input_data
         .drop(columns=['target','race','age','sex','country'])
         .fillna('Unknown')
         .pipe(pd.get_dummies, columns = ['workclass', 'education', 
                    'marital_status', 'occupation', 'relationship'], drop_first=True))

    print(f"features X: {X.shape[0]} samples, {X.shape[1]} attributes")
    print(f"features X_NC: {XNC.shape[0]} samples, {XNC.shape[1]} attributes")
    print(f"targets y: {y.shape[0]} samples")
    print(f"sensitives Z: {Z.shape[0]} samples, {Z.shape[1]} attributes")
    return X, XNC, y, Z

# load ICU data set
X, XNC, y, S = load_ICU_data('http://grarivincent.com/old/adult.data')
# Out:
# (48841, 3)
# features X: 48841 samples, 53 attributes
# features X_NC: 48841 samples, 43 attributes
# targets y: 48841 samples
# sensitives Z: 48841 samples, 1 attributes

# %%
import matplotlib.pyplot as plt

# %%
XNC
# Out:
#        race  age  ...  country_Vietnam  country_Yugoslavia
# 0         1   39  ...                0                   0
# 1         1   50  ...                0                   0
# 2         1   38  ...                0                   0
# 3         0   53  ...                0                   0
# 4         0   28  ...                0                   0
# ...     ...  ...  ...              ...                 ...
# 16276     1   39  ...                0                   0
# 16277     0   64  ...                0                   0
# 16278     1   38  ...                0                   0
# 16279     0   44  ...                0                   0
# 16280     1   35  ...                0                   0
#
# [48841 rows x 43 columns]

# %%
X
# Out:
#        fnlwgt  education_num  ...  relationship_Unmarried  relationship_Wife
# 0       77516             13  ...                       0                  0
# 1       83311             13  ...                       0                  0
# 2      215646              9  ...                       0                  0
# 3      234721              7  ...                       0                  0
# 4      338409             13  ...                       0                  1
# ...       ...            ...  ...                     ...                ...
# 16276  215419             13  ...                       0                  0
# 16277  321403              9  ...                       0                  0
# 16278  374983             13  ...                       0                  0
# 16279   83891             13  ...                       0                  0
# 16280  182148             13  ...                       0                  0
#
# [48841 rows x 53 columns]

# %%
# split into train/test set
X_train, X_test, XNC_train, XNC_test, y_train, y_test, S_train, S_test = train_test_split(X, XNC, y, S, test_size=0.2, random_state=7)

# standardize the data
scaler = MinMaxScaler().fit(X_train)
scale_df = lambda df, scaler: pd.DataFrame(scaler.transform(df), columns=df.columns, index=df.index)

scalerNC = MinMaxScaler().fit(XNC_train)
scale_dfNC = lambda df, scaler: pd.DataFrame(scalerNC.transform(df), columns=df.columns, index=df.index)

X_train, X_test = X_train.pipe(scale_df, scaler), X_test.pipe(scale_df, scaler)
XNC_train, XNC_test = XNC_train.pipe(scale_dfNC, scaler), XNC_test.pipe(scale_dfNC, scaler)
X_train, X_test, XNC_train, XNC_test, y_train, y_test = X_train.values, X_test.values, XNC_train.values, XNC_test.values, y_train.values, y_test.values

S_train, S_test =S_train.values, S_test.values
xNC=XNC
x=X

# %%
X_train.shape
# Out:
# (39072, 53)

# %%
XNC_train.shape
# Out:
# (39072, 43)

# %%
53+43+1
# Out:
# 97

# %%
X_train
# Out:
# array([[0.0948343 , 0.8       , 0.14344143, ..., 0.        , 1.        ,
#         0.        ],
#        [0.09831035, 0.6       , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.35573281, 0.8       , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.11796308, 0.6       , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.0704316 , 0.8       , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.14809064, 0.53333333, 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# HGR

# %%
dimlatent=5
import torch
import torch.nn as nn
import torch.nn.functional as F
H = 15
H2 = 15

class Net_HGR(nn.Module):
    def __init__(self):
        super(Net_HGR, self).__init__()
        self.fc1 = nn.Linear(dimlatent, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, H2)
        self.fc4 = nn.Linear(H2, 1)
        self.bn1 = nn.BatchNorm1d(1)

    def forward(self, x):
        h1 = torch.relu(self.fc1(x))
        h2 = torch.relu(self.fc2(h1))
        h3 = torch.relu(self.fc3(h2))
        h4 = self.fc4(h3)
        return h4

class Net2_HGR(nn.Module):
    def __init__(self):
        super(Net2_HGR, self).__init__()
        self.fc1 = nn.Linear(43, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, H2)
        self.fc4 = nn.Linear(H2, 1)
        self.bn1 = nn.BatchNorm1d(1)

    def forward(self, x):
        h1 = torch.relu(self.fc1(x))
        h2 = torch.relu(self.fc2(h1))
        h3 = torch.relu(self.fc3(h2))
        h4 = self.fc4(h3)
        return h4    

class HGR_NN(nn.Module):
    
    def __init__(self,model_F,model_G):
        super(HGR_NN, self).__init__()
        self.mF = model_F
        self.mG = model_G
        self.optimizer_F = torch.optim.Adam(self.mF.parameters(), lr=0.001)
        self.optimizer_G = torch.optim.Adam(self.mG.parameters(), lr=0.001)

    def forward(self, yhat, y2_var,nb):
      
        for j in range(nb) :

            pred_F  = self.mF(yhat.detach())
            pred_G  = self.mG(y2_var.detach())
           
            epsilon=0.0001 
            pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
            pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))
            pred_F_norm[torch.isnan(pred_F_norm )] = 0
            pred_G_norm[torch.isnan(pred_G_norm )] = 0

            ret = torch.mean(pred_F_norm*pred_G_norm)
            loss = - ret  # maximize
            self.mF.zero_grad()
            self.mG.zero_grad()
            loss.backward()
            #print(loss)
            self.optimizer_F.step()
            self.optimizer_G.step()
            
        return ret

# %% [markdown]
# # Variational Autoencoder

# %%
from __future__ import print_function
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
from torch.autograd import Variable
batch_size=128
epochs=10
seed=1
log_interval=10
device = torch.device("cuda")
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        #self.fc1NC = nn.Linear(97, 400)  # La dimension de la data est de 94 variables et on rajoute la variable sensible A pour construire l'espace latent U
        #self.fc21NC = nn.Linear(400, 20) # ici c'est pour la moyenne on part sur 20 neurones en deuxiemes couches
        #self.fc22NC = nn.Linear(400, 20) # ici c'est pour les écarts types avec toujours 20 neurones sur la deuxieme couche
 
        self.fc1S = nn.Linear(97, 400)  # La dimension de la data est de 94 variables et on rajoute la variable sensible A pour construire l'espace latent U
        self.fc21S = nn.Linear(400, dimlatent) # ici c'est pour la moyenne on part sur 20 neurones en deuxiemes couches
        self.fc22S = nn.Linear(400, dimlatent) # ici c'est pour les écarts types avec toujours 20 neurones sur la deuxieme couche

        self.fc3I = nn.Linear(xNC.shape[1]+dimlatent, 400) # ici c'est la partie decodeur
        self.fc4I = nn.Linear(400, x.shape[1]) # on revient sur une data sur le nombre de variables de X
        #self.fc42NC = nn.Linear(400, 1) # on prédit uniquement Y => donc une seule colonne

        self.fc3Y = nn.Linear(96+dimlatent , 400) # ici c'est la partie decodeur
        self.fc41Y = nn.Linear(400, 1) # on revient sur une data sur le nombre de variables de X


    def encodeS(self, x, xNC, y) :
        h1 = F.relu(self.fc1S(torch.cat([xNC.view(-1, xNC.shape[1]),x.view(-1, x.shape[1]),y.view(-1, 1)],1)))  # on utilise une simple ReLu pour la premiere couche de 400 neurones et ID pour la deuxieme couche pour u et std
        return self.fc21S(h1), self.fc22S(h1)

    #def encodeI(self, x, xNC, y, a, S) :
    #    h1 = F.relu(self.fc1I(torch.cat([xNC.view(-1, 43),S],1)))  # on utilise une simple ReLu pour la premiere couche de 400 neurones et ID pour la deuxieme couche pour u et std
    #    return self.fc21I(h1)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)  # racine de la variance ==> std
        eps = torch.randn_like(std)   # une loi normal entre 0 et 1 avec une taille de std soit de 20 !!
        #eps =1
        return mu + eps*std  # z = u + sigm * eps

    def decodeI(self,  x, xNC, y, S):
        h3 = F.relu(self.fc3I(torch.cat([xNC.view(-1, xNC.shape[1]),S],1))) # la 3eme couche et donc la premiere couche du decoder a une relu avec 400 neurones 
        return torch.sigmoid(self.fc4I(h3))#, torch.sigmoid(self.fc42NC(h3)) # la 4 eme couche et dernier on souhaite retrouver une data on met une sigmoid car on a quelque chose entre . et 1

    def decodeY(self,  x, xNC, y, S, XIrec):
        #print(torch.cat([xNC.view(-1, 43),XIrec.view(-1, 53), S],1).shape)
        h3 = F.relu(self.fc3Y(torch.cat([xNC.view(-1, xNC.shape[1]),x.view(-1, x.shape[1]), S],1))) # la 3eme couche et donc la premiere couche du decoder a une relu avec 400 neurones 
        return torch.sigmoid(self.fc41Y(h3)) # la 4 eme couche et dernier on souhaite retrouver une data on met une sigmoid car on a quelque chose entre . et 1

    def forward(self, x, xNC, y):
        muS, logvarS = self.encodeS(x, xNC, y)  # on recupere le X et on obtient le u et la logvar qui va nous servir à calculer z en reparameterize trick
        S = self.reparameterize(muS, logvarS) # en deuxieme couche une fois qu on recupere u et sigma on utilise une loi normal entre 0 et 1 u + sigmaµ eps
        recon_XI_batch = self.decodeI(x, xNC, y, S)
        recon_Y_batch = self.decodeY(x, xNC, y,  S, recon_XI_batch)

        #mu1, logvar1 = self.encode(x.view(-1, 94), a)  # on recupere le X et on obtient le u et la logvar qui va nous servir à calculer z en reparameterize trick
        #z1 = self.reparameterize(mu1, logvar1) # en deuxieme couche une fois qu on recupere u et sigma on utilise une loi normal entre 0 et 1 u + sigmaµ eps
        #mu0, logvar0 = self.encode(x.view(-1, 94), a)  # on recupere le X et on obtient le u et la logvar qui va nous servir à calculer z en reparameterize trick
        #z0 = self.reparameterize(mu0, logvar0) # en deuxieme couche une fois qu on recupere u et sigma on utilise une loi normal entre 0 et 1 u + sigmaµ eps
        return  recon_XI_batch, S, recon_Y_batch, muS, logvarS # on decode ici pour retrouver une image ici


class Demographic(nn.Module):
    def __init__(self):
        super(Adversarial, self).__init__()
        self.adv_fc1 = nn.Linear(44, 6)
        self.adv_fc2 = nn.Linear(6, 2)
        self.adv_fc3 = nn.Linear(2, 1)

    def forward(self, x):
        x = self.adv_fc1(x)
        x = F.relu(x)
        #x = F.dropout(x, p=0.8)
        x = self.adv_fc2(x)
        x = F.relu(x)
        #x = F.dropout(x, p=0.8)
        x = self.adv_fc3(x)
        x = F.sigmoid(x)
        return x

class Adversarial(nn.Module):
    def __init__(self):
        super(Adversarial, self).__init__()
        self.adv_fc1 = nn.Linear(20, 6)
        self.adv_fc2 = nn.Linear(6, 2)
        self.adv_fc3 = nn.Linear(2, 2)

    def forward(self, x):
        x = self.adv_fc1(x)
        x = F.relu(x)
        #x = F.dropout(x, p=0.8)
        x = self.adv_fc2(x)
        x = F.relu(x)
        #x = F.dropout(x, p=0.8)
        x = self.adv_fc3(x)
        x = F.relu(x)
        return x
   
def compute_kernel(x, y):
    x_size = x.size(0)
    y_size = y.size(0)
    dim = x.size(1)
    tiled_x = x.unsqueeze(1).repeat(1, y_size, 1)
    tiled_y = y.unsqueeze(0).repeat(x_size, 1, 1)
    #print('x', x)
    #print('x', y)
    #print('xshape', x.shape)
    #print('yshapbinary_cross_entropy', y.shape)
    #print('tiled_x',tiled_x)
    #print('tiled_y',tiled_y)
    return ((-(tiled_x - tiled_y) ** 2).mean(dim=2) / float(dim)).exp_()

def compute_mmd(x, y):
    x_kernel = compute_kernel(x, x)
    y_kernel = compute_kernel(y, y)
    xy_kernel = compute_kernel(x, y)
    mmd = x_kernel.mean() + y_kernel.mean() - 2*xy_kernel.mean()
    return mmd

# %%
from __future__ import print_function
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
from sklearn.utils import shuffle
from torch.autograd import Variable

latent_dim=5
model = VAE().cuda()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

mF = Net_HGR().cuda()
mG = Net2_HGR().cuda()
optimizer_F = optim.Adam(mF.parameters(), lr=1e-4)
optimizer_G = optim.Adam(mG.parameters(), lr=1e-4)
epsilon=0.0001

betaX = 1.5
betammd = 0.1
betahgr = 0#0.5

batch_idx=0
batch_size=2000
epochs=200
epochs_hgr=50
seed=1
log_interval=1
batch_no = len(X_train) // batch_size

for epoch in range(epochs):

  x_train, x_trainNC, ytrain, senstrain = shuffle(X_train, XNC_train , np.expand_dims(y_train,axis = 1), S_train)
  
  average_total_loss = 0
  average_lossX = 0
  average_mmd = 0
  average_lossY = 0
  average_mmdS = 0
  average_hgr = 0
  betahgr2=betahgr
  # Mini batch learning  
  for i in range(batch_no):
    
    start = i * batch_size
    end = start + batch_size
    x_var = Variable(torch.FloatTensor(x_train[start:end])).cuda()
    x_varNC = Variable(torch.FloatTensor(x_trainNC[start:end])).cuda()
    y_var = Variable(torch.FloatTensor(ytrain[start:end])).cuda()
    s_var = Variable(torch.FloatTensor(senstrain[start:end])).cuda()
    recon_x, S, recon_y, mu, logvar = model(x_var, x_varNC, y_var)
    
    #if (epoch ==10) & (i<5) :
    #  for k in range(400) :
    #    optimizer_F.zero_grad()
    #    optimizer_G.zero_grad()
    #    
    #    pred_F  = mF(s_var.detach())
    #    pred_G  = mG(z.view(-1, latent_dim).detach())
    #    pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
    #    pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))

    #    ret = torch.mean(pred_F_norm*pred_G_norm)
    #    loss_HGR = - ret  # maximize
    #    loss_HGR.backward()

    #    optimizer_F.step()
    #    optimizer_G.step()

    if epoch > 30 :
      betahgr2=betahgr
      for k in range(epochs_hgr):
        
        optimizer_F.zero_grad()
        optimizer_G.zero_grad()
        
        pred_F  = mF(S.detach().cuda())
        pred_G  = mG(x_varNC.detach().cuda()) #,x_var.detach().cuda(),y_var.detach().cuda()],1))
        pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
        pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))

        ret = torch.mean(pred_F_norm*pred_G_norm)
        loss_HGR = - ret  # maximize
        loss_HGR.backward()

        optimizer_F.step()
        optimizer_G.step()


    optimizer.zero_grad()
    recon_XI, S, recon_y, mu, logvar = model(x_var, x_varNC, y_var)
    lossX = F.binary_cross_entropy(recon_XI, x_var.view(-1, recon_XI.shape[1]), reduction='mean')
    lossY = F.binary_cross_entropy(recon_y, y_var.view(-1, 1), reduction='mean')

    #lossXNC = F.binary_cross_entropy(recon_xNC, x_varNC.view(-1, 43), reduction='mean')

    true_samplesS = Variable(
               torch.randn(x_var.shape[0], 1),
                requires_grad=False
            ).to(device)
    mmdS = compute_mmd(true_samplesS, S)

    #mmd =0
    #KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    ### Training the adversary for epochs_adv epochs
    
    pred_F  = mF(S)
    pred_G  = mG(x_varNC)
    pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
    pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))
    ret = torch.mean(pred_F_norm*pred_G_norm)
    loss = betaX*lossX + betaX*lossY + betammd*mmdS + betahgr2*ret
    loss.backward()
    optimizer.step()

    ## Average losses on the whole data
    average_total_loss += loss.item()
    average_lossX += lossX.item()
    average_lossY += lossY.item()
    average_mmdS += mmdS.item()
    average_hgr += ret.item()
    
  if epoch % log_interval == 0:
    print('====> Epoch: {} Total loss: {:.4f} || Loss X: {:.4f} || Loss Y: {:.4f} || HGR: {:.4f} || HGR: {:.4f} '.format(epoch, average_total_loss / batch_no, average_lossX / batch_no, average_lossY/ batch_no, average_mmd / batch_no, average_hgr / batch_no ))#,'MSE :', np.mean((y_train - recon_Y_batch.detach().numpy())**2))
# Out:
# ====> Epoch: 0 Total loss: 1.7217 || Loss X: 0.5296 || Loss Y: 0.5745 || HGR: 0.0000 || HGR: 0.0014
# ====> Epoch: 1 Total loss: 1.1517 || Loss X: 0.2817 || Loss Y: 0.4396 || HGR: 0.0000 || HGR: 0.0010
# ====> Epoch: 2 Total loss: 0.8496 || Loss X: 0.2502 || Loss Y: 0.2737 || HGR: 0.0000 || HGR: 0.0048
# ====> Epoch: 3 Total loss: 0.5248 || Loss X: 0.2317 || Loss Y: 0.0703 || HGR: 0.0000 || HGR: 0.0057
# ====> Epoch: 4 Total loss: 0.4169 || Loss X: 0.2278 || Loss Y: 0.0060 || HGR: 0.0000 || HGR: 0.0066
# ====> Epoch: 5 Total loss: 0.3920 || Loss X: 0.2177 || Loss Y: 0.0034 || HGR: 0.0000 || HGR: 0.0060
# ====> Epoch: 6 Total loss: 0.3743 || Loss X: 0.2096 || Loss Y: 0.0028 || HGR: 0.0000 || HGR: 0.0057
# ====> Epoch: 7 Total loss: 0.3598 || Loss X: 0.2028 || Loss Y: 0.0019 || HGR: 0.0000 || HGR: 0.0049
# ====> Epoch: 8 Total loss: 0.3463 || Loss X: 0.1957 || Loss Y: 0.0013 || HGR: 0.0000 || HGR: 0.0032
# ====> Epoch: 9 Total loss: 0.3325 || Loss X: 0.1874 || Loss Y: 0.0014 || HGR: 0.0000 || HGR: -0.0008
# ====> Epoch: 10 Total loss: 0.3151 || Loss X: 0.1765 || Loss Y: 0.0009 || HGR: 0.0000 || HGR: -0.0031
# ====> Epoch: 11 Total loss: 0.2968 || Loss X: 0.1648 || Loss Y: 0.0008 || HGR: 0.0000 || HGR: -0.0035
# ====> Epoch: 12 Total loss: 0.2826 || Loss X: 0.1559 || Loss Y: 0.0007 || HGR: 0.0000 || HGR: -0.0045
# ====> Epoch: 13 Total loss: 0.2694 || Loss X: 0.1478 || Loss Y: 0.0004 || HGR: 0.0000 || HGR: -0.0037
# ====> Epoch: 14 Total loss: 0.2573 || Loss X: 0.1401 || Loss Y: 0.0003 || HGR: 0.0000 || HGR: -0.0035
# ====> Epoch: 15 Total loss: 0.2478 || Loss X: 0.1341 || Loss Y: 0.0004 || HGR: 0.0000 || HGR: -0.0035
# ====> Epoch: 16 Total loss: 0.2414 || Loss X: 0.1300 || Loss Y: 0.0003 || HGR: 0.0000 || HGR: -0.0043
# ====> Epoch: 17 Total loss: 0.2364 || Loss X: 0.1266 || Loss Y: 0.0004 || HGR: 0.0000 || HGR: -0.0034
# ====> Epoch: 18 Total loss: 0.2310 || Loss X: 0.1234 || Loss Y: 0.0002 || HGR: 0.0000 || HGR: -0.0040
# ====> Epoch: 19 Total loss: 0.2265 || Loss X: 0.1203 || Loss Y: 0.0003 || HGR: 0.0000 || HGR: -0.0034
# ====> Epoch: 20 Total loss: 0.2221 || Loss X: 0.1173 || Loss Y: 0.0003 || HGR: 0.0000 || HGR: -0.0036
# ====> Epoch: 21 Total loss: 0.2175 || Loss X: 0.1146 || Loss Y: 0.0003 || HGR: 0.0000 || HGR: -0.0039
# ====> Epoch: 22 Total loss: 0.2144 || Loss X: 0.1122 || Loss Y: 0.0004 || HGR: 0.0000 || HGR: -0.0028
# ====> Epoch: 23 Total loss: 0.2136 || Loss X: 0.1112 || Loss Y: 0.0005 || HGR: 0.0000 || HGR: -0.0045
# ====> Epoch: 24 Total loss: 0.2090 || Loss X: 0.1086 || Loss Y: 0.0002 || HGR: 0.0000 || HGR: -0.0049
# ====> Epoch: 25 Total loss: 0.2054 || Loss X: 0.1065 || Loss Y: 0.0002 || HGR: 0.0000 || HGR: -0.0048
# ====> Epoch: 26 Total loss: 0.2028 || Loss X: 0.1047 || Loss Y: 0.0003 || HGR: 0.0000 || HGR: -0.0041
# ====> Epoch: 27 Total loss: 0.2000 || Loss X: 0.1032 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: -0.0047
# ====> Epoch: 28 Total loss: 0.1982 || Loss X: 0.1016 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: -0.0046
# ====> Epoch: 29 Total loss: 0.1954 || Loss X: 0.0999 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: -0.0048
# ====> Epoch: 30 Total loss: 0.1937 || Loss X: 0.0987 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: -0.0056
# ====> Epoch: 31 Total loss: 0.1914 || Loss X: 0.0972 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.4067
# ====> Epoch: 32 Total loss: 0.1887 || Loss X: 0.0957 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.6724
# ====> Epoch: 33 Total loss: 0.1893 || Loss X: 0.0954 || Loss Y: 0.0006 || HGR: 0.0000 || HGR: 0.7192
# ====> Epoch: 34 Total loss: 0.1864 || Loss X: 0.0939 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.7350
# ====> Epoch: 35 Total loss: 0.1839 || Loss X: 0.0922 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.7444
# ====> Epoch: 36 Total loss: 0.1822 || Loss X: 0.0910 || Loss Y: 0.0002 || HGR: 0.0000 || HGR: 0.7484
# ====> Epoch: 37 Total loss: 0.1816 || Loss X: 0.0904 || Loss Y: 0.0003 || HGR: 0.0000 || HGR: 0.7526
# ====> Epoch: 38 Total loss: 0.1789 || Loss X: 0.0890 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.7536
# ====> Epoch: 39 Total loss: 0.1774 || Loss X: 0.0879 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.7571
# ====> Epoch: 40 Total loss: 0.1760 || Loss X: 0.0869 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.7618
# ====> Epoch: 41 Total loss: 0.1744 || Loss X: 0.0860 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.7620
# ====> Epoch: 42 Total loss: 0.1729 || Loss X: 0.0850 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.7632
# ====> Epoch: 43 Total loss: 0.1712 || Loss X: 0.0840 || Loss Y: 0.0000 || HGR: 0.0000 || HGR: 0.7654
# ====> Epoch: 44 Total loss: 0.1704 || Loss X: 0.0832 || Loss Y: 0.0002 || HGR: 0.0000 || HGR: 0.7655
# ====> Epoch: 45 Total loss: 0.1687 || Loss X: 0.0824 || Loss Y: 0.0000 || HGR: 0.0000 || HGR: 0.7655
# ====> Epoch: 46 Total loss: 0.1716 || Loss X: 0.0832 || Loss Y: 0.0009 || HGR: 0.0000 || HGR: 0.7704
# ====> Epoch: 47 Total loss: 0.1717 || Loss X: 0.0838 || Loss Y: 0.0003 || HGR: 0.0000 || HGR: 0.7724
# ====> Epoch: 48 Total loss: 0.1683 || Loss X: 0.0816 || Loss Y: 0.0002 || HGR: 0.0000 || HGR: 0.7729
# ====> Epoch: 49 Total loss: 0.1653 || Loss X: 0.0798 || Loss Y: 0.0001 || HGR: 0.0000 || HGR: 0.7725
# ====> Epoch: 50 Total loss: 0.1641 || Loss X: 0.0790 || Loss Y: 0.0002 || HGR: 0.0000 || HGR: 0.7746
# ====> Epoch: 51 Total loss: 0.1623 || Loss X: 0.0779 || Loss Y: 0.0000 || HGR: 0.0000 || HGR: 0.7742
# ====> Epoch: 52 Total loss: 0.1622 || Loss X: 0.0775 || Loss Y: 0.0004 || HGR: 0.0000 || HGR: 0.7754
# ====> Epoch: 53 Total loss: 0.1600 || Loss X: 0.0763 || Loss Y: 0.0000 || HGR: 0.0000 || HGR: 0.7738
# ====> Epoch: 54 Total loss: 0.1584 || Loss X: 0.0755 || Loss Y: 0.0000 || HGR: 0.0000 || HGR: 0.7778
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-0799fa98925a> in <module>()
#      87         loss_HGR.backward()
#      88
# ---> 89         optimizer_F.step()
#      90         optimizer_G.step()
#      91
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     116                    lr=group['lr'],
#     117                    weight_decay=group['weight_decay'],
# --> 118                    eps=group['eps'])
#     119         return loss
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      85         # Decay the first and second moment running average coefficient
#      86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#      89             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
x_varNC.shape
# Out:
# torch.Size([2000, 43])

# %%
torch.save(model.state_dict(), "WithoutDemographic_adult5_5_" + str(betahgr),_use_new_zipfile_serialization=False)

# %%
model_VAE = VAE().to(device)
model_VAE.load_state_dict(torch.load("WithoutDemographic_adult5_150and020 (2).2"))
# Out:
# <All keys matched successfully>

# %%
model = model_VAE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a81ef569ab0d> in <module>()
# ----> 1 model = model_VAE
#
# NameError: name 'model_VAE' is not defined

# %%
X_trainCUDA = Variable(torch.FloatTensor(X_train)).cuda()
XNC_trainCUDA = Variable(torch.FloatTensor(XNC_train)).cuda()
y_trainCUDA = Variable(torch.FloatTensor(np.expand_dims(y_train,axis = 1))).cuda()

X_testCUDA = Variable(torch.FloatTensor(X_test)).cuda()
XNC_testCUDA = Variable(torch.FloatTensor(XNC_test)).cuda()
y_testCUDA = Variable(torch.FloatTensor(np.expand_dims(y_test,axis = 1))).cuda()

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
nb_a=1
Sreal = Variable(torch.FloatTensor(np.expand_dims(y_train,axis = 1))).repeat(nb_a,1).data.numpy()
recon_x, S, recon_y, mu, logvar = model(X_trainCUDA.repeat(nb_a,1).view(-1, 53), XNC_trainCUDA.repeat(nb_a,1).view(-1, 43), y_trainCUDA.repeat(nb_a,1).view(-1, 1))
reg.fit (S.cpu().data.numpy(), Sreal)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Sreal, (((reg.predict(S.cpu().data.numpy()).astype('uint8'))>0.5)))
# Out:
# 0.7634111384111384

# %%
H = 15
H2 = 15
epochs_hgr=50
class Net_HGR(nn.Module):
    def __init__(self):
        super(Net_HGR, self).__init__()
        self.fc1 = nn.Linear(dimlatent, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, H2)
        self.fc4 = nn.Linear(H2, 1)
        self.bn1 = nn.BatchNorm1d(1)
    def forward(self, x):
        h1 = torch.tanh(self.fc1(x))
        h2 = torch.relu(self.fc2(h1))
        h3 = torch.tanh(self.fc3(h2))
        h4 = self.fc4(h3)
        return h4    
class Net2_HGR(nn.Module):
    def __init__(self):
        super(Net2_HGR, self).__init__()
        self.fc1 = nn.Linear(1, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, H2)
        self.fc4 = nn.Linear(H2, 1)
        self.bn1 = nn.BatchNorm1d(1)
    def forward(self, x):
        h1 = torch.tanh(self.fc1(x))
        h2 = torch.relu(self.fc2(h1))
        h3 = torch.tanh(self.fc3(h2))
        h4 = self.fc4(h3)
        return h4    
HGR_NNP = HGR_NN(Net_HGR(),Net2_HGR())
print("HGR NN Test",HGR_NNP(Variable(torch.FloatTensor(S.cpu().data.numpy())) , Variable(torch.FloatTensor(Sreal)).repeat(nb_a,1).view(-1, 1),100))
# Out:
# HGR NN Test tensor(0.6570, grad_fn=<MeanBackward0>)

# %%
data_subset=S.cpu().data.numpy().copy()

# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=300)
tsne_results = tsne.fit_transform(data_subset)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 39072 samples in 0.039s...
# [t-SNE] Computed neighbors for 39072 samples in 3.492s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 39072
# [t-SNE] Computed conditional probabilities for sample 2000 / 39072
# [t-SNE] Computed conditional probabilities for sample 3000 / 39072
# [t-SNE] Computed conditional probabilities for sample 4000 / 39072
# [t-SNE] Computed conditional probabilities for sample 5000 / 39072
# [t-SNE] Computed conditional probabilities for sample 6000 / 39072
# [t-SNE] Computed conditional probabilities for sample 7000 / 39072
# [t-SNE] Computed conditional probabilities for sample 8000 / 39072
# [t-SNE] Computed conditional probabilities for sample 9000 / 39072
# [t-SNE] Computed conditional probabilities for sample 10000 / 39072
# [t-SNE] Computed conditional probabilities for sample 11000 / 39072
# [t-SNE] Computed conditional probabilities for sample 12000 / 39072
# [t-SNE] Computed conditional probabilities for sample 13000 / 39072
# [t-SNE] Computed conditional probabilities for sample 14000 / 39072
# [t-SNE] Computed conditional probabilities for sample 15000 / 39072
# [t-SNE] Computed conditional probabilities for sample 16000 / 39072
# [t-SNE] Computed conditional probabilities for sample 17000 / 39072
# [t-SNE] Computed conditional probabilities for sample 18000 / 39072
# [t-SNE] Computed conditional probabilities for sample 19000 / 39072
# [t-SNE] Computed conditional probabilities for sample 20000 / 39072
# [t-SNE] Computed conditional probabilities for sample 21000 / 39072
# [t-SNE] Computed conditional probabilities for sample 22000 / 39072
# [t-SNE] Computed conditional probabilities for sample 23000 / 39072
# [t-SNE] Computed conditional probabilities for sample 24000 / 39072
# [t-SNE] Computed conditional probabilities for sample 25000 / 39072
# [t-SNE] Computed conditional probabilities for sample 26000 / 39072
# [t-SNE] Computed conditional probabilities for sample 27000 / 39072
# [t-SNE] Computed conditional probabilities for sample 28000 / 39072
# [t-SNE] Computed conditional probabilities for sample 29000 / 39072
# [t-SNE] Computed conditional probabilities for sample 30000 / 39072
# [t-SNE] Computed conditional probabilities for sample 31000 / 39072
# [t-SNE] Computed conditional probabilities for sample 32000 / 39072
# [t-SNE] Computed conditional probabilities for sample 33000 / 39072
# [t-SNE] Computed conditional probabilities for sample 34000 / 39072
# [t-SNE] Computed conditional probabilities for sample 35000 / 39072
# [t-SNE] Computed conditional probabilities for sample 36000 / 39072
# [t-SNE] Computed conditional probabilities for sample 37000 / 39072
# [t-SNE] Computed conditional probabilities for sample 38000 / 39072
# [t-SNE] Computed conditional probabilities for sample 39000 / 39072
# [t-SNE] Computed conditional probabilities for sample 39072 / 39072
# [t-SNE] Mean sigma: 1.350267
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.999977
# [t-SNE] KL divergence after 300 iterations: 3.802963
# t-SNE done! Time elapsed: 157.97323656082153 seconds

# %%
df_subset=pd.DataFrame(data_subset)

# %%
df_subset['Gender']=Sreal
df_subset['Gender'][df_subset['Gender']==1]= 'Female'
df_subset['Gender'][df_subset['Gender']==0]= 'Male'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
Sreal.mean()
# Out:
# 0.23776618

# %%
df_subset.shape
# Out:
# (39072, 8)

# %%
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
colors = ["#003066", "#e4141e"]
# Set your custom color palette
customPalette = sns.set_palette(sns.color_palette(colors))
plt.figure(figsize=(10,10))
sns_plot =sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Gender",
    palette=customPalette,
    data=df_subset,
    legend="full",
    alpha=0.3
)

sns_plot.figure.savefig("output.pdf")
#fig.savefig("/content/drive/MyDrive/Withoutdemo/T-sne" + str(betamse)+ 'P-rule=' + str(round(PRULE.cpu().data.numpy()*100,1)) + '.pdf')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
H = 15
H2 = 15
epochs_hgr=50

class Net_HGR(nn.Module):
    def __init__(self):
        super(Net_HGR, self).__init__()
        self.fc1 = nn.Linear(dimlatent, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, H2)
        self.fc4 = nn.Linear(H2, 1)
        self.bn1 = nn.BatchNorm1d(1)

    def forward(self, x):
        h1 = torch.tanh(self.fc1(x))
        h2 = torch.relu(self.fc2(h1))
        h3 = torch.tanh(self.fc3(h2))
        h4 = self.fc4(h3)
        return h4    


class Net2_HGR(nn.Module):
    def __init__(self):
        super(Net2_HGR, self).__init__()
        self.fc1 = nn.Linear(1, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, H2)
        self.fc4 = nn.Linear(H2, 1)
        self.bn1 = nn.BatchNorm1d(1)

    def forward(self, x):
        h1 = torch.tanh(self.fc1(x))
        h2 = torch.relu(self.fc2(h1))
        h3 = torch.tanh(self.fc3(h2))
        h4 = self.fc4(h3)
        return h4    


model_Net_F = Net_HGR()
model_Net_G = Net2_HGR()

class HGR_NN(nn.Module):
    
    def __init__(self,model_F,model_G):
        super(HGR_NN, self).__init__()
        self.mF = model_Net_F
        self.mG = model_Net_G
        self.optimizer_F = torch.optim.Adam(self.mF.parameters(), lr=0.001)
        self.optimizer_G = torch.optim.Adam(self.mG.parameters(), lr=0.001)

    def forward(self, yhat, y2_var,nb):
      
        for j in range(nb) :
            #ret = torch.mean(pred_xy) - torch.log(torch.mean(torch.exp(pred_x_y)))
            #ret = torch.mean(pred_xy) - torch.mean(pred_x_y) - 0.25*torch.mean(torch.pow(pred_x_y,2))

            yhat2  =yhat.data.numpy()
            y2_var2=y2_var.data.numpy()
        
            yhat2_PT  = torch.from_numpy(yhat2).type(torch.FloatTensor)
            y2_var_PT = torch.from_numpy(y2_var2).type(torch.FloatTensor)

            pred_F  = self.mF(yhat2_PT)
            pred_G  = self.mG(y2_var_PT)

            pred_F_norm = (pred_F-torch.mean(pred_F))/torch.std(pred_F)
            pred_G_norm = (pred_G-torch.mean(pred_G))/torch.std(pred_G)

            #epsilon=0.0000000000000000001
            epsilon=0.0001 
            pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
            pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))
            pred_F_norm[torch.isnan(pred_F_norm )] = 0
            pred_G_norm[torch.isnan(pred_G_norm )] = 0

            ret = torch.mean(pred_F_norm*pred_G_norm)
            loss = - ret  # maximize
            self.mF.zero_grad()
            self.mG.zero_grad()
            loss.backward()
            #print(loss)
            self.optimizer_F.step()
            self.optimizer_G.step()

        return ret.data.numpy()


mF = Net_HGR().cuda()
mG = Net2_HGR().cuda()
optimizer_F = optim.Adam(mF.parameters(), lr=1e-4)
optimizer_G = optim.Adam(mG.parameters(), lr=1e-4)
epsilon=0.0001

batch_size = 256
num_epochs = 18
learning_rate = 0.0001
batch_no = len(X_train) // batch_size
#X_train_inv = recon_X_batch_a.data.numpy()
#Y_train_inv = recon_Y_batch_a.data.numpy()

from sklearn.utils import shuffle
from torch.autograd import Variable
criterionMSE = nn.MSELoss()
import math
nb_a=200
from torch.nn import functional as F
def sigmoid(x):
  output = [1 / (1 + math.exp(-x)) for x in x]
  return output

class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.fc1 = nn.Linear(96, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
        self.fc4 = nn.Linear(16, 1)        
    def forward(self, x):
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.relu(x)
        x = self.fc4(x)
        return x


model_Y = NN().cuda()
criterion = torch.nn.BCEWithLogitsLoss(reduction='mean')
optimizer_Y = torch.optim.Adam(model_Y.parameters(), lr=0.001)
criterion_ADV =  nn.MSELoss()
#A0 = sensitive.mean() + sensitive.std()*Variable(torch.randn(data.shape[0]*nb_a, 1),requires_grad=False)
#recon_X_batch_a0, z_a0, recon_Y_batch_a0, mu_a0, logvar_a0 = model(data.repeat(nb_a,1).view(-1, 33),A0)
#recon_x, recon_xNC, S, U,  recon_y, mu, logvar = model(x_var, x_varNC, y_var,s_var)
from sklearn.metrics import accuracy_score
X_trainCUDA = Variable(torch.FloatTensor(X_train)).cuda()
XNC_trainCUDA = Variable(torch.FloatTensor(XNC_train)).cuda()
y_trainCUDA = Variable(torch.FloatTensor(np.expand_dims(y_train,axis = 1))).cuda()

X_testCUDA = Variable(torch.FloatTensor(X_test)).cuda()
XNC_testCUDA = Variable(torch.FloatTensor(XNC_test)).cuda()
y_testCUDA = Variable(torch.FloatTensor(np.expand_dims(y_test,axis = 1))).cuda()
table = [0,0,0,0,0,0]
for epoch in range(num_epochs):
    #if epoch % 50 != 0:
        #x_train = Variable(torch.FloatTensor(X_train.values),requires_grad=True)
        #x_test = Variable(torch.FloatTensor(X_test.values),requires_grad=True)
        #print('Epoch {}'.format(epoch+1))
        
        #y_predX= model(x_train).data.numpy().T
        #y_predXinv= model(recon_X_batch_a0).data.numpy().T

        #accuracy = (y_train-np.squeeze(y_predX)).pow(2).sum()     
        #accuracycount = accuracy_score(Y_train_inv.squeeze(1), np.squeeze(y_predXinv))
        #print ("Train Accuracy:", accuracy)#,"Train Accuracy Count:", accuracycount, "CLP:", np.mean(logit_y_predX-logit_y_predXinv)**2)
    x_train, x_trainNC, ytrain, sens_train = shuffle(X_train, XNC_train, np.expand_dims(y_train,axis = 1),  S_train)

    #A = s_var.mean() + s_var.std()*Variable(torch.randn(batch_size*nb_a, 1),requires_grad=False)
    # Mini batch learning
    for i in range(batch_no):
        print('Epoch: ', epoch, 'Batch:',i)
        start = i * batch_size
        end = start + batch_size

        x_var = Variable(torch.FloatTensor(x_train[start:end])).cuda()
        xNC_var = Variable(torch.FloatTensor(x_trainNC[start:end])).cuda()
        y_var = Variable(torch.FloatTensor(ytrain[start:end])).cuda()
        s_var = Variable(torch.FloatTensor(sens_train[start:end])).cuda()

        #recon_X_batch_a, z_a, recon_Y_batch_a, mu_a, logvar_a = model(x_var.repeat(nb_a,1).view(-1, 53),x_var.repeat(nb_a,1).view(-1, 33))
        recon_x, S, recon_y, mu, logvar = model(x_var.repeat(nb_a,1).view(-1, 53), xNC_var.repeat(nb_a,1).view(-1, 43), y_var.repeat(nb_a,1).view(-1, 1))

        #ypredcontworld = model_Y(torch.cat([recon_xNC.view(-1, 43),recon_x.view(-1, 53)],1))
        ypredcontworld = model_Y(torch.cat([x_var.view(-1, 53),xNC_var.view(-1, 43)],1))
        lossX_inv = criterion(ypredcontworld, y_var)

        ypred2= ypredcontworld.detach()

        if epoch ==0:
          for l in range(10):
            ypred_var = model_Y(torch.cat([xNC_var.view(-1, 43),x_var.view(-1, 53)],1))
            lossY =criterion(ypred_var, y_var)
            loss = lossY #+betamse*ret # + lossX_inv -2*lossX#+ betamse*MSEcount
            print('loss tot', loss, 'loss Y', lossY)
            loss.backward()
            optimizer_Y.step()
        #S=s_var.repeat(nb_a,1).view(-1, 1)
        ypred_var2 = model_Y(torch.cat([xNC_var.repeat(nb_a,1).view(-1, 43),x_var.repeat(nb_a,1).view(-1, 53)],1))

        for k in range(epochs_hgr):
          
          optimizer_F.zero_grad()
          optimizer_G.zero_grad()
          
          pred_F  = mF(S.detach().cuda())
          pred_G  = mG(ypred_var2.detach().cuda())
          pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
          pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))

          ret = torch.mean(pred_F_norm*pred_G_norm)
          loss_HGR = - ret  # maximize
          loss_HGR.backward()

          optimizer_F.step()
          optimizer_G.step()
        #Yhat_count =  Variable(torch.FloatTensor(ypred_var.data.numpy().T.repeat(nb_a,1).T))
        #MSEcount = (Yhat_count-ypredcontworld).pow(2).sum() 
        
        optimizer_Y.zero_grad()
        ypred_var = model_Y(torch.cat([xNC_var.view(-1, 43),x_var.view(-1, 53)],1))
        ypred_var2 = model_Y(torch.cat([xNC_var.repeat(nb_a,1).view(-1, 43),x_var.repeat(nb_a,1).view(-1, 53)],1))
        lossY =criterion(ypred_var, y_var)
        betamse =0#.5#44 #7   ## LAMBDA =0.7
        pred_F  = mF(S)
        pred_G  = mG(ypred_var2)
        pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
        pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))

        ret = torch.mean(pred_F_norm*pred_G_norm)
        loss = lossY +betamse*ret # + lossX_inv -2*lossX#+ betamse*MSEcount

        if epoch ==0:
          loss = lossY  # + lossX_inv -2*lossX#+ betamse*MSEcount
        print('loss tot', loss, 'loss Y', lossY)
        print('HGR', ret)

        loss.backward()
        optimizer_Y.step()
        Ypred = torch.sigmoid(model_Y(torch.cat([XNC_trainCUDA.view(-1, 43),X_trainCUDA.view(-1, 53)],1)))>0.5
        Ho = (S_train==1)
        Fe = (S_train==0)
        odds=Ypred.float()[Ho].mean()/ Ypred.float()[Fe].mean()
        PRULE= min(odds, 1/odds)

        Ypredtest = torch.sigmoid(model_Y(torch.cat([XNC_testCUDA.view(-1, 43),X_testCUDA.view(-1, 53)],1)))>0.5
        Ho = (S_test==1)
        Fe = (S_test==0)
        odds=Ypredtest.float()[Ho].mean()/ Ypredtest.float()[Fe].mean()
        PRULEtest= min(odds, 1/odds)
        print('ACC Train',(Ypred==y_trainCUDA).sum()/X_train.shape[0], 'PRULE',PRULE, 'ACC Test',(Ypredtest==y_testCUDA).sum()/X_test.shape[0],'PRULEtest',PRULEtest)
        table = np.vstack([table,[(Ypred.cpu().data.numpy()==y_trainCUDA.cpu().data.numpy()).sum()/X_train.shape[0]*100,PRULE.cpu().data.numpy(),ret.cpu().data.numpy(), 
                                  (Ypredtest.cpu().data.numpy()==y_testCUDA.cpu().data.numpy()).sum()/X_test.shape[0]*100,PRULEtest.cpu().data.numpy(),ret.cpu().data.numpy()]])

np.savetxt(sys.stdout, np.mean(table[1:,], axis=0).astype(float), '%5.2f')
# Out:
# Epoch:  0 Batch: 0
# loss tot tensor(0.6972, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6972, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6946, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6946, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6922, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6922, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6899, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6899, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6877, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6877, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6856, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6856, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6836, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6836, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6817, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6817, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6800, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6800, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6784, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6784, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.0084, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 1
# loss tot tensor(0.6741, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6741, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6726, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6726, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6711, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6711, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6679, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6679, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6660, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6660, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6640, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6640, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6619, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6619, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6596, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6596, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6570, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6570, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6544, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6544, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.0532, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 2
# loss tot tensor(0.6553, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6553, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6529, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6529, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6505, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6505, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6479, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6479, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6452, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6452, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6422, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6422, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6390, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6390, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6355, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6355, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6317, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6317, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6276, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6276, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6232, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6232, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.1707, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 3
# loss tot tensor(0.6114, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6114, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6067, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6067, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.6020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.6020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5970, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5970, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5918, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5918, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5862, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5862, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5804, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5804, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5742, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5742, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5677, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5677, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5609, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5609, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5540, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5540, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.4682, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 4
# loss tot tensor(0.5612, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5612, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5561, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5561, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5513, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5513, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5467, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5467, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5422, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5422, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5379, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5379, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5337, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5337, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5297, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5297, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5259, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5259, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5223, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5223, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5190, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5190, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.5493, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 5
# loss tot tensor(0.5110, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5110, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5093, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5093, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5079, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5079, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5012, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4984, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4984, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4949, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4949, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4909, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4909, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4863, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4863, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6227, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 6
# loss tot tensor(0.5072, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5072, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.5035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.5035, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4997, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4997, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4958, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4958, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4918, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4918, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4876, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4876, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4835, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4835, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4796, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4796, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4757, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4757, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4722, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4722, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4690, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4690, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6967, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 7
# loss tot tensor(0.4720, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4720, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4675, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4675, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4653, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4653, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4630, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4630, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4605, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4605, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4578, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4578, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4547, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4547, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4513, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4513, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4475, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4475, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4433, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4433, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6753, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 8
# loss tot tensor(0.4225, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4225, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4196, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4196, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4167, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4167, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4137, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4137, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4105, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4105, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4039, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4039, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4005, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4005, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3972, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3972, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3941, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3941, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3914, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3914, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6723, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 9
# loss tot tensor(0.3784, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3784, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3759, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3759, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3737, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3737, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3717, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3717, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3697, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3697, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3676, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3676, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3654, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3654, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3629, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3629, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3600, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3600, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3568, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3568, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3531, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3531, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.7122, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0') ACC Test tensor(0.7546, device='cuda:0') PRULEtest tensor(nan, device='cuda:0')
# Epoch:  0 Batch: 10
# loss tot tensor(0.4472, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4472, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4463, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4463, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4445, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4445, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4418, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4418, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4385, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4385, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4348, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4348, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4312, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4312, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4282, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4282, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4262, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4262, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4253, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4253, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4257, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4257, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.7026, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8262, device='cuda:0') PRULE tensor(0.3679, device='cuda:0') ACC Test tensor(0.8267, device='cuda:0') PRULEtest tensor(0.3742, device='cuda:0')
# Epoch:  0 Batch: 11
# loss tot tensor(0.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3836, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3836, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3869, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3869, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3896, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3896, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3915, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3915, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3924, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3924, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3921, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3921, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3907, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3907, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3881, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3881, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3846, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3846, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3803, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3803, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6588, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8187, device='cuda:0') PRULE tensor(0.3331, device='cuda:0') ACC Test tensor(0.8207, device='cuda:0') PRULEtest tensor(0.3398, device='cuda:0')
# Epoch:  0 Batch: 12
# loss tot tensor(0.3998, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3998, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3972, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3972, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3946, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3946, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3923, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3923, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3900, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3900, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3878, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3878, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3859, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3859, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3845, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3845, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3835, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3835, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3832, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3832, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3836, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3836, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6865, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8278, device='cuda:0') PRULE tensor(0.3264, device='cuda:0') ACC Test tensor(0.8238, device='cuda:0') PRULEtest tensor(0.3222, device='cuda:0')
# Epoch:  0 Batch: 13
# loss tot tensor(0.3380, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3380, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3381, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3381, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3385, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3385, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3390, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3390, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3394, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3394, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3396, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3396, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3395, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3395, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3390, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3390, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3380, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3380, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3365, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3365, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3345, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3345, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.7757, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8261, device='cuda:0') PRULE tensor(0.3562, device='cuda:0') ACC Test tensor(0.8225, device='cuda:0') PRULEtest tensor(0.3460, device='cuda:0')
# Epoch:  0 Batch: 14
# loss tot tensor(0.4466, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4466, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4448, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4448, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4420, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4420, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4381, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4381, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4329, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4329, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4267, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4267, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4198, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4198, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4128, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4128, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4061, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4003, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4003, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3964, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3964, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6989, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8232, device='cuda:0') PRULE tensor(0.4170, device='cuda:0') ACC Test tensor(0.8280, device='cuda:0') PRULEtest tensor(0.4172, device='cuda:0')
# Epoch:  0 Batch: 15
# loss tot tensor(0.3535, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3535, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3600, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3600, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3665, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3665, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3723, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3723, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3769, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3769, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3798, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3798, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3809, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3809, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3769, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3769, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3720, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3720, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3657, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3657, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6388, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8190, device='cuda:0') PRULE tensor(0.3839, device='cuda:0') ACC Test tensor(0.8216, device='cuda:0') PRULEtest tensor(0.3912, device='cuda:0')
# Epoch:  0 Batch: 16
# loss tot tensor(0.4282, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4282, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4247, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4247, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4215, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4215, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4187, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4187, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4160, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4160, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4136, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4136, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4115, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4115, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4099, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4099, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4089, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4089, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4085, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4085, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4089, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4089, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6431, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8280, device='cuda:0') PRULE tensor(0.3299, device='cuda:0') ACC Test tensor(0.8233, device='cuda:0') PRULEtest tensor(0.3236, device='cuda:0')
# Epoch:  0 Batch: 17
# loss tot tensor(0.3979, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3979, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4008, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4008, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4057, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4057, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4070, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4070, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4071, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4059, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4059, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4033, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3995, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3995, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3947, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3947, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3893, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3893, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6679, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8286, device='cuda:0') PRULE tensor(0.3130, device='cuda:0') ACC Test tensor(0.8236, device='cuda:0') PRULEtest tensor(0.3076, device='cuda:0')
# Epoch:  0 Batch: 18
# loss tot tensor(0.3989, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3989, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3960, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3960, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3935, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3935, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3913, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3913, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3893, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3893, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3876, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3876, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3862, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3862, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3851, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3851, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3843, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3843, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3841, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3841, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3842, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3842, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6371, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8306, device='cuda:0') PRULE tensor(0.3290, device='cuda:0') ACC Test tensor(0.8302, device='cuda:0') PRULEtest tensor(0.3365, device='cuda:0')
# Epoch:  0 Batch: 19
# loss tot tensor(0.4368, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4368, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4379, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4379, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4388, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4388, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4395, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4395, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4397, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4397, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4393, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4393, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4384, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4384, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4369, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4369, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4348, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4348, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4321, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4321, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4288, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4288, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6943, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8308, device='cuda:0') PRULE tensor(0.3415, device='cuda:0') ACC Test tensor(0.8294, device='cuda:0') PRULEtest tensor(0.3538, device='cuda:0')
# Epoch:  0 Batch: 20
# loss tot tensor(0.3831, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3831, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3821, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3821, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3810, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3810, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3789, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3789, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3778, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3778, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3758, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3758, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3748, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3748, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3739, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3739, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3730, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3730, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.7293, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8336, device='cuda:0') PRULE tensor(0.2697, device='cuda:0') ACC Test tensor(0.8305, device='cuda:0') PRULEtest tensor(0.2560, device='cuda:0')
# Epoch:  0 Batch: 21
# loss tot tensor(0.3643, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3643, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3651, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3651, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3655, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3655, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3653, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3653, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3643, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3643, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3625, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3625, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3598, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3598, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3564, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3564, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3524, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3524, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3483, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3483, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3443, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3443, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.6695, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8325, device='cuda:0') PRULE tensor(0.2958, device='cuda:0') ACC Test tensor(0.8324, device='cuda:0') PRULEtest tensor(0.2964, device='cuda:0')
# Epoch:  0 Batch: 22
# ...
# loss tot tensor(0.4043, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4043, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4021, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4021, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4011, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4001, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4001, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3990, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3990, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3979, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3979, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3968, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3968, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3959, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3959, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3952, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3952, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.8057, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8369, device='cuda:0') PRULE tensor(0.3522, device='cuda:0') ACC Test tensor(0.8359, device='cuda:0') PRULEtest tensor(0.3403, device='cuda:0')
# Epoch:  0 Batch: 34
# loss tot tensor(0.3753, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3753, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3773, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3773, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3792, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3792, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3808, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3808, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3818, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3818, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3822, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3822, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3817, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3817, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3804, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3804, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3749, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3749, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3711, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3711, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.8118, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8358, device='cuda:0') PRULE tensor(0.3561, device='cuda:0') ACC Test tensor(0.8366, device='cuda:0') PRULEtest tensor(0.3507, device='cuda:0')
# Epoch:  0 Batch: 35
# loss tot tensor(0.3455, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3455, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3454, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3454, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3453, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3453, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3452, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3452, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3450, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3450, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3447, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3447, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3443, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3443, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3436, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3436, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3426, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3426, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3412, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3412, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3395, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3395, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.7667, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8328, device='cuda:0') PRULE tensor(0.3786, device='cuda:0') ACC Test tensor(0.8364, device='cuda:0') PRULEtest tensor(0.3660, device='cuda:0')
# Epoch:  0 Batch: 36
# loss tot tensor(0.3198, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3198, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3199, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3199, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3199, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3199, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3198, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3198, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3194, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3194, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3188, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3188, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3180, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3180, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3169, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3169, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3156, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3156, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3142, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3142, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3126, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3126, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.7635, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8345, device='cuda:0') PRULE tensor(0.3538, device='cuda:0') ACC Test tensor(0.8351, device='cuda:0') PRULEtest tensor(0.3538, device='cuda:0')
# Epoch:  0 Batch: 37
# loss tot tensor(0.3697, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3697, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3694, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3694, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3690, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3690, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3686, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3686, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3679, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3679, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3670, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3670, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3659, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3659, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3646, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3646, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3630, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3630, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3610, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3610, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3587, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3587, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.7881, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8364, device='cuda:0') PRULE tensor(0.3173, device='cuda:0') ACC Test tensor(0.8353, device='cuda:0') PRULEtest tensor(0.3257, device='cuda:0')
# Epoch:  0 Batch: 38
# loss tot tensor(0.3724, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3724, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3722, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3722, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3719, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3719, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3715, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3715, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3711, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3711, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3704, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3704, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3686, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3686, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3675, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3675, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3663, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3663, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.3649, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.3649, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# HGR tensor(0.7900, device='cuda:0', grad_fn=<MeanBackward0>)
# ACC Train tensor(0.8363, device='cuda:0') PRULE tensor(0.3249, device='cuda:0') ACC Test tensor(0.8372, device='cuda:0') PRULEtest tensor(0.3328, device='cuda:0')
# Epoch:  0 Batch: 39
# loss tot tensor(0.4117, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4117, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4108, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4108, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4099, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4099, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4089, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4089, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4066, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# loss tot tensor(0.4000, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>) loss Y tensor(0.4000, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-3a8920cd91ff> in <module>()
#     199
#     200           pred_F  = mF(S.detach().cuda())
# --> 201           pred_G  = mG(ypred_var2.detach().cuda())
#     202           pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
#     203           pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-46-3a8920cd91ff> in forward(self, x)
#      35     def forward(self, x):
#      36         h1 = torch.tanh(self.fc1(x))
# ---> 37         h2 = torch.relu(self.fc2(h1))
#      38         h3 = torch.tanh(self.fc3(h2))
#      39         h4 = self.fc4(h3)
#
# KeyboardInterrupt:

# %%
Ypred = torch.sigmoid(model_Y(torch.cat([XNC_trainCUDA.view(-1, 43),X_trainCUDA.view(-1, 53)],1)))>0.5
Ho = (S_train==1)
Fe = (S_train==0)
odds=Ypred.float()[Ho].mean()/ Ypred.float()[Fe].mean()
PRULE= min(odds, 1/odds)
print('Prule Train: ', PRULE)
# Out:
# Prule Train:  tensor(0.3259, device='cuda:0')

# %%
filter  = 0
iter = range(table[filter:].shape[0])
ACC = table[:,0]
PRULE = table[:,1]
HGR = table[:,2]

fig, ax1 = plt.subplots()
ax1.set_facecolor('white')
ax1.grid(color='gray', linestyle=':', linewidth=1)
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 18.0
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax1.plot(iter, ACC/100, color = 'green',label="Acc")
ax1.plot(iter, PRULE, color = 'blue',label="Prule")
ax1.plot(iter, HGR, color = 'red',label="HGR")
#leg = plt.legend(loc="best", edgecolor="gray",facecolor="gray")
#plt.ylim(0,25)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
plt.xlabel("number of iterations", fontsize=12)
#plt.ylabel("P(f(X))", fontsize=12)
plt.legend(loc="upper left")
plt.savefig("f-plain.pdf")
plt.legend(loc='upper center', bbox_to_anchor=(0.75, 0.3),shadow=False, ncol=1, fontsize=11,facecolor='lavender')
#plt.show()
plt.title('Fair model ($\lambda$ =' + str(betamse) + '; P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) +'%)', fontsize=12)
fig.savefig("Trainingcurves_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')
fig.savefig("/content/drive/MyDrive/Withoutdemo/Trainingcurves_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')

plt.show()
plt.clf()

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
ax1 = plt.subplot(311)   
ax1.set_facecolor('white')
ax1.grid(color='gray',which='major', linestyle=':', linewidth=1)
x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 16.0
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
values = np.array(ACC/100)
plt.plot(range(len(values)), values, label=r"$L_f$",linewidth=1, markersize=12)
#plt.legend(loc="upper right")

ax2 = plt.subplot(312, sharex=ax1) 
ax2.set_facecolor('white')
ax2.grid(color='gray',which='minor' ,linestyle=':', linewidth=1,alpha=0.2)
ax2.minorticks_on()
x_axis2 = ax2.axes.get_xaxis()
x_axis2.set_visible(False)
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 18.0
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
values = np.array(PRULE) 
plt.plot(range(len(values)), values, label=r"$L_r$", color="green",linewidth=1, markersize=12)
#plt.legend(loc="upper right")

ax3 = plt.subplot(313, sharex=ax1)
ax3.set_facecolor('white')
ax3.grid(color='gray', linestyle=':', linewidth=1)
x_axis3 = ax3.axes.get_xaxis()
x_axis3.set_visible(False)
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 18.0
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
values = np.array(HGR)
plt.plot(range(len(values)), values, label=r"$L_f - \lambda L_r$", color="red",linewidth=1, markersize=12)
#plt.legend(loc="upper right")

plt.show()

# %%
import matplotlib.pyplot as plt 
plt.rcdefaults()

# %%
values[-10:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6f2922068554> in <module>()
# ----> 1 values[-10:]
#
# NameError: name 'values' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
    from matplotlib.pyplot import figure
    figure(figsize=(6.5, 4.8), dpi=80)
    import matplotlib.pyplot as plt
    ax1 = plt.subplot(311)  
    values = np.array(ACC/100)
    plt.plot(range(len(values)), values, color="blue",linewidth=1, markersize=12)
    plt.grid(True)  
    ax1.spines.linewidth=0
    min_Lf=np.mean(values[-2:])
    n_iter=ACC.shape[0]
    plt.hlines(min_Lf, 0, n_iter, linestyles="dashed",linewidth=1)
    low = min(min_Lf, values.min())
    high = max(min_Lf, values.max())
    #high = high - (high-low) * 0.3
    low, high = low - (high-low)*0.1, high + (high-low)*0.1
    plt.ylim(0.7, 0.9)
    plt.xticks([])
    plt.xlim(0, n_iter)
    ax1.yaxis.set_major_locator(ticker.MultipleLocator(0.05))
    plt.grid(True, linestyle='dotted')
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.ylabel(r"Acc", fontsize=10)
    
    ax2 = plt.subplot(312, sharex=ax1) 
    values = PRULE 
    plt.plot(range(len(values)), values, color="green",linewidth=1, markersize=12)  
    min_Lf=np.mean(values[-20:])
    n_iter=ACC.shape[0]
    plt.hlines(min_Lf, 0, n_iter, linestyles="dashed",linewidth=1)
    low = min(min_Lf, values.min())
    high = max(min_Lf, values.max())
    #high = high - (high-low) * 0.3
    low, high = low - (high-low)*0.1, high + (high-low)*0.1
    plt.ylim(0, 1)
    plt.xticks([])
    plt.xlim(0, n_iter)
    ax2.yaxis.set_major_locator(ticker.MultipleLocator(0.25))
    plt.grid(True, linestyle='dotted')
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    #plt.ylabel(r"P-rule($\widehat{Y}$,S)", fontsize=10)
    plt.ylabel(r"P-rule", fontsize=10)
    
    ax3 = plt.subplot(313)
    values = np.array(HGR)
    plt.plot(range(len(values)), values, color="red",linewidth=1, markersize=12)  
    min_Lf=np.mean(values[-10:])
    n_iter=ACC.shape[0]
    plt.hlines(min_Lf, 0, n_iter, linestyles="dashed",linewidth=1)
    low = min(min_Lf, values.min())
    high = max(min_Lf, values.max())
    #low = low + (high-low) * 0.5
    low, high = low - (high-low)*0.1, high + (high-low)*0.1
    plt.ylim(low, 1)
    plt.xlim(0, n_iter)
    ax3.yaxis.set_major_locator(ticker.MultipleLocator(0.25))
    plt.grid(axis="y", linestyle='dotted')
    #plt.ylabel("HGR($\widehat{Y}$,Z)", fontsize=10)
    plt.ylabel("HGR", fontsize=10)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.xlabel("Number of iterations", fontsize=10)
    ax3.tick_params(direction='out', length=2, width=1,
                grid_alpha=1)
plt.rcParams["font.size"] = 10
plt.savefig("Trainingcurves_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')
plt.savefig("/content/drive/MyDrive/Withoutdemo/Trainingcurves_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-05e563a33f67> in <module>()
#      17 plt.xticks([])
#      18 plt.xlim(0, n_iter)
# ---> 19 ax1.yaxis.set_major_locator(ticker.MultipleLocator(0.05))
#      20 plt.grid(True, linestyle='dotted')
#      21 plt.xticks(fontsize=10)
#
# NameError: name 'ticker' is not defined

# %%
data1 = y_pred[100:,1]
data2 = y_pred[100:,3]
t = range(281)
fig, ax1 = plt.subplots()
ax1.set_facecolor('white')
ax1.grid(color='gray', linestyle=':', linewidth=1)
color = 'tab:blue'
ax1.set_xlabel('number of iterations')
ax1.set_ylim(0.5, 1)
ax1.set_ylabel('Classification accuracy %', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.grid(color='gray', linestyle=':', linewidth=1)
ax2.set_ylabel('p%-rule %', color=color)  # we already handled the x-label with ax1
ax2.set_ylim(0.5, 1)
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Unfair model (FAGTB with $\lambda$=%1.3f)"  %lamb)
plt.show()
val = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-af3cf5fba741> in <module>()
# ----> 1 data1 = y_pred[100:,1]
#       2 data2 = y_pred[100:,3]
#       3 t = range(281)
#       4 fig, ax1 = plt.subplots()
#       5 ax1.set_facecolor('white')
#
# NameError: name 'y_pred' is not defined

# %%
ACC.mean()
# Out:
# 80.76594380942207

# %%
ACC.mean()
# Out:
# 80.76594380942207

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt


Ypredtest = torch.sigmoid(model_Y(torch.cat([XNC_testCUDA.view(-1, 43),X_testCUDA.view(-1, 53)],1)))>0.5
Ho = (S_test==1)
Fe = (S_test==0)
odds=Ypredtest.float()[Ho].mean()/ Ypredtest.float()[Fe].mean()
PRULEtest= min(odds, 1/odds)
print(PRULEtest)
Ypredtest = torch.sigmoid(model_Y(torch.cat([XNC_testCUDA.view(-1, 43),X_testCUDA.view(-1, 53)],1)))
#plt.tick_params(axis = "x", which = "both", bottom = False, top = False)

fig, ax1 = plt.subplots(linewidth=20.5)
for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(1.5)
ax1.set_facecolor('white')
ax1.grid(color='gray', linestyle=':', linewidth=1)
ax1.tick_params( axis='both', bottom = False, top = False)
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 18.0
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax1.hist(Ypredtest.float()[Ho].cpu().data.numpy(), color = 'green',bins=50, density=1, histtype="step", label="$p(f(X)|S=1)$",linewidth=2)
ax1.hist(Ypredtest.float()[Fe].cpu().data.numpy(), color = 'red',bins=50, density=1,histtype="step", label="$p(f(X)|S=0)$",linewidth=1.5)
leg = plt.legend(loc="best", edgecolor="white",facecolor="white")
plt.ylim(0,25)
#ax1.spines['top'].set_visible(False)
#ax1.spines['bottom'].set_visible(False)
#ax1.spines['right'].set_visible(False)
#ax1.spines['left'].set_visible(False)
plt.xlabel("$f(X)$", fontsize=18)
plt.ylabel("P(f(X))", fontsize=18)
plt.legend(loc="upper left")
plt.savefig("f-plain.pdf")
plt.legend(loc='upper center', bbox_to_anchor=(0.67, 0.9),shadow=False, ncol=1, fontsize=18)
#plt.show()
plt.title('Fair model ($\lambda$ =' + str(betamse) + '; P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) +'%)', fontsize=18)
fig.savefig("Test_distrib25_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')
fig.savefig("/content/drive/MyDrive/Withoutdemo/Test_distrib_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')

plt.show()
plt.clf()
# Out:
# tensor(0.7037, device='cuda:0')

# %%
Ypredtest = torch.sigmoid(model_Y(torch.cat([XNC_testCUDA.view(-1, 43),X_testCUDA.view(-1, 53)],1)))>0.5
Ho = (S_test==1)
Fe = (S_test==0)
odds=Ypredtest.float()[Ho].mean()/ Ypredtest.float()[Fe].mean()
PRULEtest= min(odds, 1/odds)
print(PRULEtest)
Ypredtest = torch.sigmoid(model_Y(torch.cat([XNC_testCUDA.view(-1, 43),X_testCUDA.view(-1, 53)],1)))
#plt.
from matplotlib.pyplot import figure
#figure(num=None, figsize=(2, 3), dpi=80, facecolor='w', edgecolor='k')
fig, ax1 = plt.subplots()
ax1.tick_params(  bottom = False, top = False)
#ax1.axes.yaxis.set_ticks(bottom = False)
import matplotlib.pyplot as plt
#plt.rcParams["figure.figsize"] = (2,2.8)
for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(1.5)
ax1.set_ylim( bottom = False)
#ax1.axes.xaxis.set_ticks([])
#ax1.axes.yaxis.set_ticks([])

ax1.set_facecolor('white')
ax1.grid(color='gray', linestyle=':', linewidth=1)
#plt.rcParams["figure.figsize"] = (3,3)
plt.rcParams["font.size"] = 18.0
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax1.hist(Ypredtest.float()[Ho].cpu().data.numpy(), color = 'green',bins=50, density=1, histtype="step", label="$p(h_{\\theta}(a,x_{d})|S=1)$",linewidth=1.5)
ax1.hist(Ypredtest.float()[Fe].cpu().data.numpy(), color = 'red',bins=50, density=1,histtype="step", label="$p(h_{\\theta}(a,x_{d})|S=0)$",linewidth=1.5)
leg = plt.legend(loc="best", edgecolor="white",facecolor="white")
plt.ylim(0,24)
#ax1.spines['top'].set_visible(False)
#ax1.spines['bottom'].set_visible(False)
#ax1.spines['right'].set_visible(False)
#ax1.spines['left'].set_visible(False)
plt.xlabel("$h_{\\theta}(a,x_{d})$", fontsize=18)
plt.ylabel("p($h_{\\theta}(a,x_{d})$)", fontsize=18)
plt.legend(loc="upper left")
plt.savefig("f-plain.pdf")
plt.legend(loc='upper center', bbox_to_anchor=(0.66, 0.9),shadow=False, ncol=1, fontsize=18)
#plt.show()
plt.title('Fair model ($\lambda$ =' + str(betamse) + '; P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) +'%)', fontsize=18)
fig.savefig("Test_distrib25_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')
fig.savefig("/content/drive/MyDrive/Withoutdemo/Test_distrib_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')

plt.show()
plt.clf()
# Out:
# tensor(0.7037, device='cuda:0')

# %%
Ypredtest = torch.sigmoid(model_Y(torch.cat([XNC_testCUDA.view(-1, 43),X_testCUDA.view(-1, 53)],1)))>0.5
Ho = (S_test==1)
Fe = (S_test==0)
odds=Ypredtest.float()[Ho].mean()/ Ypredtest.float()[Fe].mean()
PRULEtest= min(odds, 1/odds)
print(PRULEtest)
Ypredtest = torch.sigmoid(model_Y(torch.cat([XNC_testCUDA.view(-1, 43),X_testCUDA.view(-1, 53)],1)))

fig, ax1 = plt.subplots()
ax1.set_facecolor('white')
ax1.grid(color='gray', linestyle=':', linewidth=1)
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 18.0
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax1.hist(Ypredtest.float()[Ho].cpu().data.numpy(), color = 'green',bins=50, density=1, histtype="step", label="$p(f(X)|S=1)$")
ax1.hist(Ypredtest.float()[Fe].cpu().data.numpy(), color = 'red',bins=50, density=1,histtype="step", label="$p(f(X)|S=0)$")
leg = plt.legend(loc="best", edgecolor="white",facecolor="white")
#plt.ylim(0,25)
#ax1.spines['top'].set_visible(False)
#ax1.spines['bottom'].set_visible(False)
#ax1.spines['right'].set_visible(False)
#ax1.spines['left'].set_visible(False)
plt.xlabel("$f(X)$", fontsize=12)
plt.ylabel("P(f(X))", fontsize=12)
plt.legend(loc="upper left")
plt.savefig("f-plain.pdf")
plt.legend(loc='upper center', bbox_to_anchor=(0.75, 0.9),shadow=False, ncol=1, fontsize=11)
#plt.show()
plt.title('Fair model ($\lambda$ =' + str(betamse) + '; P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) +'%)', fontsize=12)
fig.savefig("Test_distrib_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')
fig.savefig("/content/drive/MyDrive/Withoutdemo/Test_distrib_lam" + str(betamse)+ 'P-rule=' + str(round(PRULEtest.cpu().data.numpy()*100,1)) + '.pdf')

plt.show()
plt.clf()
# Out:
# tensor(0.3333, device='cuda:0')

# %%
Ypred = torch.sigmoid(model_Y(torch.cat([XNC_trainCUDA.view(-1, 43),X_trainCUDA.view(-1, 53)],1)))>0.5
Ho = (S_train==1)
Fe = (S_train==0)
odds=Ypred.float()[Ho].mean()/ Ypred.float()[Fe].mean()
PRULE= min(odds, 1/odds)
print('Prule Train: ', PRULE)
# Out:
# Prule Train:  tensor(0.9668, device='cuda:0')

# %%
Ypred = torch.sigmoid(model_Y(torch.cat([XNC_trainCUDA.view(-1, 43),X_trainCUDA.view(-1, 53)],1)))
Ho = (S_train==1)
Fe = (S_train==0)
import matplotlib.pyplot as plt


fig, ax1 = plt.subplots()
ax1.set_facecolor('white')
ax1.grid(color='gray', linestyle=':', linewidth=1)
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 18.0
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax1.hist(Ypred.float()[Ho].cpu().data.numpy(), color = 'green',bins=50, density=1, histtype="step", label="$p(f(X)|S=1)$")
ax1.hist(Ypred.float()[Fe].cpu().data.numpy(), color = 'red',bins=50, density=1,histtype="step", label="$p(f(X)|S=0)$")
leg = plt.legend(loc="best", edgecolor="gray",facecolor="gray")
plt.ylim(0,25)
#ax1.spines['top'].set_visible(False)
#ax1.spines['bottom'].set_visible(False)
#ax1.spines['right'].set_visible(False)
#ax1.spines['left'].set_visible(False)
plt.xlabel("$f(X)$", fontsize=12)
plt.ylabel("P(f(X))", fontsize=12)
plt.legend(loc="upper left")
plt.savefig("f-plain.pdf")
plt.legend(loc='upper center', bbox_to_anchor=(0.75, 0.9),shadow=False, ncol=1, fontsize=11)
#plt.show()
plt.title('Fair model ($\lambda$ =' + str(betamse) + '; P-rule=' + str(round(PRULE.cpu().data.numpy()*100,1)) +'%)', fontsize=12)
fig.savefig("Train_distrib25_lam" + str(betamse)+ 'P-rule=' + str(round(PRULE.cpu().data.numpy()*100,1)) + '.pdf')
fig.savefig("/content/drive/MyDrive/Withoutdemo/Train_distrib_lam" + str(betamse)+ 'P-rule=' + str(round(PRULE.cpu().data.numpy()*100,1)) + '.pdf')

plt.show()
plt.clf()

# %%
PRULEYpred = torch.sigmoid(model_Y(torch.cat([XNC_trainCUDA.view(-1, 43),X_trainCUDA.view(-1, 53)],1)))
Ho = (S_train==1)
Fe = (S_train==0)
import matplotlib.pyplot as plt


fig, ax1 = plt.subplots()
ax1.set_facecolor('white')
ax1.grid(color='gray', linestyle=':', linewidth=1)
plt.rcParams["figure.figsize"] = (6,6)
plt.rcParams["font.size"] = 18.0
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax1.hist(Ypred.float()[Ho].cpu().data.numpy(), color = 'green',bins=50, density=1, histtype="step", label="$p(f(X)|S=1)$")
ax1.hist(Ypred.float()[Fe].cpu().data.numpy(), color = 'red',bins=50, density=1,histtype="step", label="$p(f(X)|S=0)$")
leg = plt.legend(loc="best", edgecolor="gray",facecolor="gray")
#plt.ylim(0,25)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
plt.xlabel("$f(X)$", fontsize=12)
plt.ylabel("P(f(X))", fontsize=12)
plt.legend(loc="upper left")
plt.savefig("f-plain.pdf")
plt.legend(loc='upper center', bbox_to_anchor=(0.75, 0.9),shadow=False, ncol=1, fontsize=11)
#plt.show()
plt.title('Fair model ($\lambda$ =' + str(betamse) + '; P-rule=' + str(round(PRULE.cpu().data.numpy()*100,1)) +'%)', fontsize=12)
fig.savefig("Train_distrib_lam" + str(betamse)+ 'P-rule=' + str(round(PRULE.cpu().data.numpy()*100,1)) + '.pdf')
fig.savefig("/content/drive/MyDrive/Withoutdemo/Train_distrib_lam" + str(betamse)+ 'P-rule=' + str(round(PRULE.cpu().data.numpy()*100,1)) + '.pdf')


plt.show()
plt.clf()

# %%
Ypred.float()[Ho]
# Out:
# tensor([1.7833e-01, 2.2503e-01, 6.0685e-01,  ..., 3.3115e-04, 3.6208e-01,
#         2.7815e-01], device='cuda:0', grad_fn=<IndexBackward>)

# %%
import sys

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
nb_a=1
Sreal = Variable(torch.FloatTensor(np.expand_dims(y_train,axis = 1))).repeat(nb_a,1).data.numpy()
recon_x, S, recon_y, mu, logvar = model(X_trainCUDA.repeat(nb_a,1).view(-1, 53), XNC_trainCUDA.repeat(nb_a,1).view(-1, 43), y_trainCUDA.repeat(nb_a,1).view(-1, 1))
reg.fit (S.cpu().data.numpy(), Sreal)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Sreal, (((reg.predict(S.cpu().data.numpy()).astype('uint8'))>0.5)))
# Out:
# 0.7643069205569205

# %%
# lambda = 0
HGR_NNP = HGR_NN(Net_HGR(),Net2_HGR())
print("HGR NN Test",HGR_NNP(Variable(torch.FloatTensor(S.cpu().data.numpy())) , Variable(torch.FloatTensor(Sreal)).repeat(nb_a,1).view(-1, 1),100))
# Out:
# HGR NN Test 0.7302409

# %%
data_subset=S.cpu().data.numpy().copy()

# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=300)
tsne_results = tsne.fit_transform(data_subset)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 39072 samples in 0.030s...
# [t-SNE] Computed neighbors for 39072 samples in 2.489s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 39072
# [t-SNE] Computed conditional probabilities for sample 2000 / 39072
# [t-SNE] Computed conditional probabilities for sample 3000 / 39072
# [t-SNE] Computed conditional probabilities for sample 4000 / 39072
# [t-SNE] Computed conditional probabilities for sample 5000 / 39072
# [t-SNE] Computed conditional probabilities for sample 6000 / 39072
# [t-SNE] Computed conditional probabilities for sample 7000 / 39072
# [t-SNE] Computed conditional probabilities for sample 8000 / 39072
# [t-SNE] Computed conditional probabilities for sample 9000 / 39072
# [t-SNE] Computed conditional probabilities for sample 10000 / 39072
# [t-SNE] Computed conditional probabilities for sample 11000 / 39072
# [t-SNE] Computed conditional probabilities for sample 12000 / 39072
# [t-SNE] Computed conditional probabilities for sample 13000 / 39072
# [t-SNE] Computed conditional probabilities for sample 14000 / 39072
# [t-SNE] Computed conditional probabilities for sample 15000 / 39072
# [t-SNE] Computed conditional probabilities for sample 16000 / 39072
# [t-SNE] Computed conditional probabilities for sample 17000 / 39072
# [t-SNE] Computed conditional probabilities for sample 18000 / 39072
# [t-SNE] Computed conditional probabilities for sample 19000 / 39072
# [t-SNE] Computed conditional probabilities for sample 20000 / 39072
# [t-SNE] Computed conditional probabilities for sample 21000 / 39072
# [t-SNE] Computed conditional probabilities for sample 22000 / 39072
# [t-SNE] Computed conditional probabilities for sample 23000 / 39072
# [t-SNE] Computed conditional probabilities for sample 24000 / 39072
# [t-SNE] Computed conditional probabilities for sample 25000 / 39072
# [t-SNE] Computed conditional probabilities for sample 26000 / 39072
# [t-SNE] Computed conditional probabilities for sample 27000 / 39072
# [t-SNE] Computed conditional probabilities for sample 28000 / 39072
# [t-SNE] Computed conditional probabilities for sample 29000 / 39072
# [t-SNE] Computed conditional probabilities for sample 30000 / 39072
# [t-SNE] Computed conditional probabilities for sample 31000 / 39072
# [t-SNE] Computed conditional probabilities for sample 32000 / 39072
# [t-SNE] Computed conditional probabilities for sample 33000 / 39072
# [t-SNE] Computed conditional probabilities for sample 34000 / 39072
# [t-SNE] Computed conditional probabilities for sample 35000 / 39072
# [t-SNE] Computed conditional probabilities for sample 36000 / 39072
# [t-SNE] Computed conditional probabilities for sample 37000 / 39072
# [t-SNE] Computed conditional probabilities for sample 38000 / 39072
# [t-SNE] Computed conditional probabilities for sample 39000 / 39072
# [t-SNE] Computed conditional probabilities for sample 39072 / 39072
# [t-SNE] Mean sigma: 0.460790
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.741440

# %%
df_subset=pd.DataFrame(data_subset)

# %%
df_subset['gender']=Sreal

# %%
df_subset.shape
# Out:
# (2000, 5)

# %%
Ypred = torch.sigmoid(model_Y(torch.cat([XNC_trainCUDA.view(-1, 43),X_trainCUDA.view(-1, 53)],1)))>0.5
Ho = (S_train==1)
Fe = (S_train==0)
odds=Ypred.float()[Ho].mean()/ Ypred.float()[Fe].mean()
PRULE= min(odds, 1/odds)
print('Prule Train: ', PRULE)
# Out:
# Prule Train:  tensor(0.2743, device='cuda:0')

# %%
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns_plot =sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="gender",
    palette=sns.color_palette("hls", 2),
    data=df_subset,
    legend="full",
    alpha=0.3
)

sns_plot.figure.savefig("output.png")
#fig.savefig("/content/drive/MyDrive/Withoutdemo/T-sne" + str(betamse)+ 'P-rule=' + str(round(PRULE.cpu().data.numpy()*100,1)) + '.pdf')

# %%
PRULE
# Out:
# tensor(0.2743, device='cuda:0')

# %%
Variable(torch.FloatTensor(S.cpu().data.numpy())).shape
# Out:
# torch.Size([39072, 5])

# %%
reg.predict(S.cpu().data.numpy())>0.5
# Out:
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
S.cpu().data.numpy().shape
# Out:
# (102400, 5)

# %%
table.shape
# Out:
# (757, 4)

# %%
((np.mean(ytrain)-ytrain)**2).mean()
# Out:
# 0.18123342116546975

# %%
optimizer_F.step()
optimizer_G.step()

# %%
x_var.repeat(2,1).view(-1, 53)[512,:]
# Out:
# tensor([0.1038, 0.8667, 0.0000, 0.0000, 0.4286, 0.0000, 0.0000, 1.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#        device='cuda:0')

# %%
recon_x.view(-1, 53)[512,:]
# Out:
# tensor([1.1372e-01, 9.4376e-01, 3.7464e-02, 5.1506e-02, 4.6568e-01, 6.8853e-04,
#         7.0738e-06, 9.9365e-01, 1.7038e-03, 3.3817e-04, 7.0279e-03, 7.6302e-06,
#         4.2219e-05, 6.7876e-08, 1.9976e-04, 4.4793e-04, 1.1422e-04, 2.0017e-05,
#         3.9951e-05, 7.9316e-04, 4.2150e-04, 4.8491e-04, 1.0855e-02, 2.2881e-06,
#         9.9103e-01, 1.0416e-04, 1.8059e-02, 4.7201e-03, 4.6958e-05, 9.8309e-01,
#         2.4383e-03, 1.8188e-04, 1.6986e-04, 2.9051e-04, 4.8375e-05, 4.1403e-05,
#         1.1247e-04, 3.2112e-08, 1.1689e-04, 1.6853e-04, 1.5927e-06, 8.7486e-04,
#         9.9372e-01, 1.5026e-03, 1.0383e-04, 8.3573e-03, 1.1785e-02, 1.1206e-05,
#         3.0427e-04, 4.5111e-05, 3.0104e-03, 1.0166e-02, 3.7463e-03],
#        device='cuda:0', grad_fn=<SliceBackward>)

# %%
batch_size = 512
num_epochs = 2000
learning_rate = 0.0001
batch_no = len(X_train) // batch_size
#X_train_inv = recon_X_batch_a.data.numpy()
#Y_train_inv = recon_Y_batch_a.data.numpy()

from sklearn.utils import shuffle
from torch.autograd import Variable
criterionMSE = nn.MSELoss()
import math
nb_a=200
from torch.nn import functional as F
def sigmoid(x):
  output = [1 / (1 + math.exp(-x)) for x in x]
  return output

class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.fc1 = nn.Linear(96, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
        self.fc4 = nn.Linear(16, 1)        
    def forward(self, x):
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.relu(x)
        x = self.fc4(x)
        return x
class ADV(nn.Module):
    def __init__(self):
        super(ADV, self).__init__()
        self.fc1 = nn.Linear(1, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
        self.fc4 = nn.Linear(16, 1)        
    def forward(self, x):
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        x = torch.relu(x)
        x = self.fc4(x)
        return x
table = [0,0,0,0]
model_Y = NN().cuda()
model_ADV = ADV().cuda()
criterion = torch.nn.BCEWithLogitsLoss(reduction='mean')
optimizer_Y = torch.optim.Adam(model_Y.parameters(), lr=0.001)
criterion_ADV =  nn.MSELoss()
optimizer_ADV = torch.optim.Adam(model_ADV.parameters(), lr=learning_rate)
#A0 = sensitive.mean() + sensitive.std()*Variable(torch.randn(data.shape[0]*nb_a, 1),requires_grad=False)
#recon_X_batch_a0, z_a0, recon_Y_batch_a0, mu_a0, logvar_a0 = model(data.repeat(nb_a,1).view(-1, 33),A0)
#recon_x, recon_xNC, S, U,  recon_y, mu, logvar = model(x_var, x_varNC, y_var,s_var)
from sklearn.metrics import accuracy_score
X_trainCUDA = Variable(torch.FloatTensor(X_train)).cuda()
XNC_trainCUDA = Variable(torch.FloatTensor(XNC_train)).cuda()
y_trainCUDA = Variable(torch.FloatTensor(np.expand_dims(y_train,axis = 1))).cuda()

for epoch in range(num_epochs):
    #if epoch % 50 != 0:
        #x_train = Variable(torch.FloatTensor(X_train.values),requires_grad=True)
        #x_test = Variable(torch.FloatTensor(X_test.values),requires_grad=True)
        #print('Epoch {}'.format(epoch+1))
        
        #y_predX= model(x_train).data.numpy().T
        #y_predXinv= model(recon_X_batch_a0).data.numpy().T

        #accuracy = (y_train-np.squeeze(y_predX)).pow(2).sum()     
        #accuracycount = accuracy_score(Y_train_inv.squeeze(1), np.squeeze(y_predXinv))
        #print ("Train Accuracy:", accuracy)#,"Train Accuracy Count:", accuracycount, "CLP:", np.mean(logit_y_predX-logit_y_predXinv)**2)
    x_train, x_trainNC, ytrain, sens_train = shuffle(X_train, XNC_train, np.expand_dims(y_train,axis = 1),  S_train)
    #A = s_var.mean() + s_var.std()*Variable(torch.randn(batch_size*nb_a, 1),requires_grad=False)
    # Mini batch learning
    for i in range(batch_no):
        print(i)
        start = i * batch_size
        end = start + batch_size

        x_var = Variable(torch.FloatTensor(x_train[start:end])).cuda()
        xNC_var = Variable(torch.FloatTensor(x_trainNC[start:end])).cuda()
        y_var = Variable(torch.FloatTensor(ytrain[start:end])).cuda()
        s_var = Variable(torch.FloatTensor(sens_train[start:end])).cuda()

        #recon_X_batch_a, z_a, recon_Y_batch_a, mu_a, logvar_a = model(x_var.repeat(nb_a,1).view(-1, 53),x_var.repeat(nb_a,1).view(-1, 33))
        recon_x, recon_xNC, S, U,  recon_y, mu, logvar = model(x_var.repeat(nb_a,1).view(-1, 53), xNC_var.repeat(nb_a,1).view(-1, 43), y_var.repeat(nb_a,1).view(-1, 1),s_var.repeat(nb_a,1).view(-1, 1))

        optimizer_Y.zero_grad()
        ypred_var = model_Y(torch.cat([xNC_var.view(-1, 43),x_var.view(-1, 53)],1))
        lossY =criterion(ypred_var, y_var)

        ypredcontworld = model_Y(torch.cat([recon_xNC.view(-1, 43),recon_x.view(-1, 53)],1))
        lossX_inv = criterion(ypredcontworld, recon_y)

        ypred2= ypredcontworld.detach()
        for k in range(10):
          optimizer_ADV.zero_grad()
          ypred_ADV = model_ADV(ypred2)
          lossX =criterion_ADV(ypred_ADV,S)
          optimizer_ADV.step()
        #Yhat_count =  Variable(torch.FloatTensor(ypred_var.data.numpy().T.repeat(nb_a,1).T))
        #MSEcount = (Yhat_count-ypredcontworld).pow(2).sum() 
        
        betamse =300.0
        ypred_ADV = model_ADV(ypred2)
        lossX =criterion_ADV(ypred_ADV,s_var.repeat(nb_a,1).view(-1, 1))
        loss = lossY -betamse*lossX # + lossX_inv -2*lossX#+ betamse*MSEcount
        print(loss)
        print(lossX)
        loss.backward()
        optimizer_Y.step()
        Ypred = torch.sigmoid(model_Y(torch.cat([XNC_trainCUDA.view(-1, 43),X_trainCUDA.view(-1, 53)],1)))>0.5
        Ho = (S_train==1)
        Fe = (S_train==0)
        odds=Ypred.float()[Ho].mean()/ Ypred.float()[Fe].mean()
        PRULE= min(odds, 1/odds)
        print('ACC',(Ypred==y_trainCUDA).sum()/X_train.shape[0], 'PRULE',PRULE)
        table = np.vstack([table,[(Ypred==y_trainCUDA).sum()/X_train.shape[0]*100,PRULE,Res['DispFPR'],Res['DispFNR']]])
np.savetxt(sys.stdout, np.mean(table[1:,], axis=0).astype(float), '%5.2f')
# Out:
# 0
# tensor(-206.1055, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6894, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 1
# tensor(-197.5755, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6610, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 2
# tensor(-215.7894, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7217, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 3
# tensor(-215.1595, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7196, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 4
# tensor(-196.2959, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6567, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 5
# tensor(-197.4915, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6607, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 6
# tensor(-207.1889, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6930, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 7
# tensor(-212.6339, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7111, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 8
# tensor(-213.2147, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7131, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 9
# tensor(-208.9362, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6988, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 10
# tensor(-204.6608, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6846, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 11
# tensor(-211.9200, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7087, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 12
# tensor(-214.9271, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7188, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(1., device='cuda:0')
# 13
# tensor(-206.3945, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6903, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2378, device='cuda:0') PRULE tensor(0.9999, device='cuda:0')
# 14
# tensor(-210.6006, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7043, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.2549, device='cuda:0') PRULE tensor(0.9770, device='cuda:0')
# 15
# tensor(-213.5632, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7142, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.4369, device='cuda:0') PRULE tensor(0.7704, device='cuda:0')
# 16
# tensor(-191.6510, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6411, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.6986, device='cuda:0') PRULE tensor(0.4785, device='cuda:0')
# 17
# tensor(-212.1866, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7096, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7547, device='cuda:0') PRULE tensor(0.4225, device='cuda:0')
# 18
# tensor(-210.8882, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7053, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7618, device='cuda:0') PRULE tensor(0.4444, device='cuda:0')
# 19
# tensor(-213.8111, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7150, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7623, device='cuda:0') PRULE tensor(0., device='cuda:0')
# 20
# tensor(-204.6163, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6843, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 21
# tensor(-203.9027, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6819, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 22
# tensor(-206.2117, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6896, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 23
# tensor(-197.6236, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6610, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 24
# tensor(-208.3439, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6967, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 25
# tensor(-213.0119, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7123, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 26
# tensor(-206.2074, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6896, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 27
# tensor(-206.6519, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6910, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 28
# tensor(-185.4193, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6202, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 29
# tensor(-211.7295, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7079, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 30
# tensor(-213.4080, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7135, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 31
# tensor(-209.6758, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7011, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 32
# tensor(-202.3377, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6766, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 33
# tensor(-203.9959, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6821, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 34
# tensor(-197.2744, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6597, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 35
# tensor(-200.0521, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6689, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 36
# tensor(-206.4229, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6901, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 37
# tensor(-195.9598, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6552, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 38
# tensor(-208.7877, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6980, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 39
# tensor(-200.7250, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6711, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 40
# tensor(-197.3993, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6600, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 41
# tensor(-196.4940, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6570, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 42
# tensor(-200.2771, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6695, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 43
# tensor(-210.5598, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7038, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 44
# tensor(-204.9398, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6851, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 45
# tensor(-205.2357, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6860, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 46
# tensor(-193.6420, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6473, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 47
# tensor(-192.7178, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6443, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 48
# tensor(-201.7860, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6744, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 49
# tensor(-193.1893, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6457, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 50
# tensor(-206.2848, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6894, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 51
# tensor(-197.1021, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6588, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 52
# tensor(-207.7930, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6944, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 53
# tensor(-199.3524, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6664, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 54
# tensor(-203.1501, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6789, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 55
# tensor(-191.3814, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6398, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 56
# tensor(-198.7305, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6641, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 57
# tensor(-207.3681, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6930, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 58
# tensor(-192.7908, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6443, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 59
# tensor(-194.5142, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6500, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 60
# tensor(-192.8050, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6444, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 61
# tensor(-203.8216, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6810, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 62
# tensor(-198.1087, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6620, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 63
# tensor(-206.1701, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6891, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 64
# tensor(-190.1482, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6354, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 65
# tensor(-197.0596, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6585, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 66
# tensor(-214.4591, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7166, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 67
# tensor(-194.3607, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6495, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 68
# tensor(-196.7560, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6574, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 69
# tensor(-193.8816, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6478, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 70
# tensor(-202.7112, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6771, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 71
# tensor(-191.0966, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6385, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 72
# tensor(-197.0202, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6584, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 73
# tensor(-199.2166, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6657, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 74
# tensor(-190.1674, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6354, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 75
# tensor(-195.4637, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6531, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 0
# tensor(-198.5084, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6632, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 1
# tensor(-193.8971, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6478, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 2
# tensor(-195.0292, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6516, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 3
# tensor(-207.7213, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6938, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 4
# tensor(-196.7698, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6572, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 5
# tensor(-204.9554, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6848, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 6
# tensor(-191.6264, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6402, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 7
# tensor(-196.4031, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6562, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 8
# tensor(-204.4632, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6830, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 9
# tensor(-205.9107, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6879, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 10
# tensor(-200.8855, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6711, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 11
# tensor(-204.8259, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6841, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 12
# tensor(-200.2767, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6690, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7622, device='cuda:0') PRULE tensor(nan, device='cuda:0')
# 13
# tensor(-193.7354, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6471, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7627, device='cuda:0') PRULE tensor(0.2686, device='cuda:0')
# 14
# tensor(-198.4096, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6628, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7630, device='cuda:0') PRULE tensor(0.5036, device='cuda:0')
# 15
# tensor(-202.6802, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6771, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7633, device='cuda:0') PRULE tensor(0.6332, device='cuda:0')
# 16
# tensor(-196.4611, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6562, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7653, device='cuda:0') PRULE tensor(0.6025, device='cuda:0')
# 17
# tensor(-211.5543, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7066, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7685, device='cuda:0') PRULE tensor(0.7245, device='cuda:0')
# 18
# tensor(-202.1758, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6753, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7718, device='cuda:0') PRULE tensor(0.6299, device='cuda:0')
# 19
# tensor(-194.6485, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6501, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7741, device='cuda:0') PRULE tensor(0.7829, device='cuda:0')
# 20
# tensor(-208.0781, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6949, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7789, device='cuda:0') PRULE tensor(0.8250, device='cuda:0')
# 21
# tensor(-201.0662, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6715, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7842, device='cuda:0') PRULE tensor(0.7240, device='cuda:0')
# 22
# tensor(-199.3145, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6656, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7914, device='cuda:0') PRULE tensor(0.5490, device='cuda:0')
# 23
# tensor(-201.3944, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6729, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.7974, device='cuda:0') PRULE tensor(0.4864, device='cuda:0')
# 24
# tensor(-209.8087, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7008, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8075, device='cuda:0') PRULE tensor(0.3540, device='cuda:0')
# 25
# tensor(-190.0987, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6349, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8121, device='cuda:0') PRULE tensor(0.3303, device='cuda:0')
# 26
# tensor(-211.6384, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7069, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8171, device='cuda:0') PRULE tensor(0.3039, device='cuda:0')
# 27
# tensor(-199.2964, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6657, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8201, device='cuda:0') PRULE tensor(0.3132, device='cuda:0')
# 28
# tensor(-196.6521, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6568, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8219, device='cuda:0') PRULE tensor(0.3263, device='cuda:0')
# 29
# tensor(-211.6533, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7069, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8233, device='cuda:0') PRULE tensor(0.3256, device='cuda:0')
# 30
# tensor(-197.6578, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6601, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8249, device='cuda:0') PRULE tensor(0.3249, device='cuda:0')
# 31
# tensor(-205.8354, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6874, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8278, device='cuda:0') PRULE tensor(0.3177, device='cuda:0')
# 32
# tensor(-201.4441, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6729, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8292, device='cuda:0') PRULE tensor(0.3210, device='cuda:0')
# 33
# tensor(-205.5897, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6866, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8299, device='cuda:0') PRULE tensor(0.3176, device='cuda:0')
# 34
# tensor(-215.1402, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7184, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8304, device='cuda:0') PRULE tensor(0.3201, device='cuda:0')
# 35
# tensor(-197.8566, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6607, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8307, device='cuda:0') PRULE tensor(0.3200, device='cuda:0')
# 36
# tensor(-211.5453, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7065, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8309, device='cuda:0') PRULE tensor(0.3155, device='cuda:0')
# 37
# tensor(-210.6022, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7034, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8313, device='cuda:0') PRULE tensor(0.3091, device='cuda:0')
# 38
# tensor(-208.3462, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6957, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8315, device='cuda:0') PRULE tensor(0.3140, device='cuda:0')
# 39
# tensor(-208.6979, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6969, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8318, device='cuda:0') PRULE tensor(0.3148, device='cuda:0')
# 40
# tensor(-194.8219, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6507, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8317, device='cuda:0') PRULE tensor(0.3162, device='cuda:0')
# 41
# tensor(-206.6702, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6902, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8315, device='cuda:0') PRULE tensor(0.3159, device='cuda:0')
# 42
# tensor(-208.5995, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6967, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8315, device='cuda:0') PRULE tensor(0.3153, device='cuda:0')
# 43
# tensor(-202.1414, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6751, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8318, device='cuda:0') PRULE tensor(0.3192, device='cuda:0')
# 44
# tensor(-200.7433, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6704, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8318, device='cuda:0') PRULE tensor(0.3243, device='cuda:0')
# 45
# tensor(-200.7446, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6705, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8318, device='cuda:0') PRULE tensor(0.3338, device='cuda:0')
# 46
# tensor(-205.1702, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6851, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8322, device='cuda:0') PRULE tensor(0.3389, device='cuda:0')
# 47
# tensor(-210.5771, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7032, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8323, device='cuda:0') PRULE tensor(0.3389, device='cuda:0')
# 48
# tensor(-207.0535, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6915, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8324, device='cuda:0') PRULE tensor(0.3381, device='cuda:0')
# 49
# tensor(-198.2351, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6621, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8327, device='cuda:0') PRULE tensor(0.3402, device='cuda:0')
# 50
# tensor(-205.8803, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6876, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8325, device='cuda:0') PRULE tensor(0.3403, device='cuda:0')
# 51
# tensor(-203.3487, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6789, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8326, device='cuda:0') PRULE tensor(0.3401, device='cuda:0')
# 52
# tensor(-206.6539, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6900, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8325, device='cuda:0') PRULE tensor(0.3409, device='cuda:0')
# 53
# tensor(-207.5894, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6932, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8326, device='cuda:0') PRULE tensor(0.3397, device='cuda:0')
# 54
# tensor(-210.7433, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7037, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8321, device='cuda:0') PRULE tensor(0.3375, device='cuda:0')
# 55
# tensor(-208.6660, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6968, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8321, device='cuda:0') PRULE tensor(0.3370, device='cuda:0')
# 56
# tensor(-201.1199, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6716, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8324, device='cuda:0') PRULE tensor(0.3358, device='cuda:0')
# 57
# tensor(-198.4411, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6627, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8324, device='cuda:0') PRULE tensor(0.3337, device='cuda:0')
# 58
# tensor(-213.2561, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7120, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8324, device='cuda:0') PRULE tensor(0.3325, device='cuda:0')
# 59
# tensor(-208.8281, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6973, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8324, device='cuda:0') PRULE tensor(0.3312, device='cuda:0')
# 60
# tensor(-217.1901, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7252, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8326, device='cuda:0') PRULE tensor(0.3303, device='cuda:0')
# 61
# tensor(-215.5742, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7198, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8327, device='cuda:0') PRULE tensor(0.3301, device='cuda:0')
# 62
# tensor(-216.3780, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7225, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8321, device='cuda:0') PRULE tensor(0.3279, device='cuda:0')
# 63
# tensor(-214.0716, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7149, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8312, device='cuda:0') PRULE tensor(0.3283, device='cuda:0')
# 64
# tensor(-206.9442, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6910, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8303, device='cuda:0') PRULE tensor(0.3334, device='cuda:0')
# 65
# tensor(-208.0478, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6946, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8301, device='cuda:0') PRULE tensor(0.3345, device='cuda:0')
# 66
# tensor(-207.5767, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6932, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8302, device='cuda:0') PRULE tensor(0.3366, device='cuda:0')
# 67
# tensor(-207.1707, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6918, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8304, device='cuda:0') PRULE tensor(0.3347, device='cuda:0')
# 68
# tensor(-198.7079, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6636, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8305, device='cuda:0') PRULE tensor(0.3340, device='cuda:0')
# 69
# tensor(-206.9492, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6911, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8309, device='cuda:0') PRULE tensor(0.3295, device='cuda:0')
# 70
# tensor(-209.0934, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6982, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8318, device='cuda:0') PRULE tensor(0.3262, device='cuda:0')
# 71
# tensor(-199.9899, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6678, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8324, device='cuda:0') PRULE tensor(0.3293, device='cuda:0')
# 72
# tensor(-208.9311, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6976, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8335, device='cuda:0') PRULE tensor(0.3303, device='cuda:0')
# 73
# tensor(-206.3283, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6890, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8343, device='cuda:0') PRULE tensor(0.3275, device='cuda:0')
# 74
# tensor(-202.8381, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6773, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8343, device='cuda:0') PRULE tensor(0.3268, device='cuda:0')
# 75
# tensor(-210.9877, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7045, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8342, device='cuda:0') PRULE tensor(0.3262, device='cuda:0')
# 0
# tensor(-207.8942, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6942, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8340, device='cuda:0') PRULE tensor(0.3267, device='cuda:0')
# 1
# tensor(-220.7011, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7369, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8336, device='cuda:0') PRULE tensor(0.3295, device='cuda:0')
# 2
# tensor(-200.8638, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6707, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8332, device='cuda:0') PRULE tensor(0.3323, device='cuda:0')
# 3
# tensor(-205.0996, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6848, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8329, device='cuda:0') PRULE tensor(0.3307, device='cuda:0')
# 4
# tensor(-204.8015, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6838, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8329, device='cuda:0') PRULE tensor(0.3308, device='cuda:0')
# 5
# tensor(-228.1055, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7619, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8328, device='cuda:0') PRULE tensor(0.3313, device='cuda:0')
# 6
# tensor(-214.4361, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7160, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8330, device='cuda:0') PRULE tensor(0.3313, device='cuda:0')
# 7
# tensor(-205.0122, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6845, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8333, device='cuda:0') PRULE tensor(0.3321, device='cuda:0')
# 8
# tensor(-210.8543, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7041, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8339, device='cuda:0') PRULE tensor(0.3294, device='cuda:0')
# 9
# tensor(-204.2429, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6821, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8345, device='cuda:0') PRULE tensor(0.3288, device='cuda:0')
# 10
# tensor(-193.5404, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6462, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8348, device='cuda:0') PRULE tensor(0.3196, device='cuda:0')
# 11
# tensor(-202.6341, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6765, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8360, device='cuda:0') PRULE tensor(0.3085, device='cuda:0')
# 12
# tensor(-211.5956, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7066, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8361, device='cuda:0') PRULE tensor(0.3029, device='cuda:0')
# 13
# tensor(-204.6356, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6832, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8366, device='cuda:0') PRULE tensor(0.3004, device='cuda:0')
# 14
# tensor(-213.0478, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7114, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8365, device='cuda:0') PRULE tensor(0.2961, device='cuda:0')
# 15
# tensor(-203.0729, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6781, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8363, device='cuda:0') PRULE tensor(0.2952, device='cuda:0')
# 16
# tensor(-202.0074, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6746, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8366, device='cuda:0') PRULE tensor(0.2937, device='cuda:0')
# 17
# tensor(-210.5118, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7029, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8366, device='cuda:0') PRULE tensor(0.2922, device='cuda:0')
# 18
# tensor(-206.0976, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6882, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8370, device='cuda:0') PRULE tensor(0.2931, device='cuda:0')
# 19
# tensor(-207.0345, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6911, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8368, device='cuda:0') PRULE tensor(0.2925, device='cuda:0')
# 20
# tensor(-218.1664, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7284, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8372, device='cuda:0') PRULE tensor(0.2931, device='cuda:0')
# 21
# tensor(-209.9824, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7012, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8370, device='cuda:0') PRULE tensor(0.2961, device='cuda:0')
# 22
# tensor(-200.0126, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6676, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8365, device='cuda:0') PRULE tensor(0.2968, device='cuda:0')
# 23
# tensor(-198.7862, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6637, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8364, device='cuda:0') PRULE tensor(0.2956, device='cuda:0')
# 24
# tensor(-202.6840, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6767, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8364, device='cuda:0') PRULE tensor(0.2940, device='cuda:0')
# 25
# tensor(-205.7119, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6870, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8370, device='cuda:0') PRULE tensor(0.2945, device='cuda:0')
# 26
# tensor(-213.8852, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7141, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8367, device='cuda:0') PRULE tensor(0.2938, device='cuda:0')
# 27
# tensor(-214.7121, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7170, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8370, device='cuda:0') PRULE tensor(0.2935, device='cuda:0')
# 28
# tensor(-197.0048, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6581, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8370, device='cuda:0') PRULE tensor(0.2932, device='cuda:0')
# 29
# tensor(-211.8328, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7073, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8370, device='cuda:0') PRULE tensor(0.2924, device='cuda:0')
# 30
# tensor(-204.6692, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6833, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8371, device='cuda:0') PRULE tensor(0.2934, device='cuda:0')
# 31
# tensor(-206.6146, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6899, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8365, device='cuda:0') PRULE tensor(0.2923, device='cuda:0')
# 32
# tensor(-200.3132, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6688, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8368, device='cuda:0') PRULE tensor(0.2921, device='cuda:0')
# 33
# tensor(-202.7232, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6769, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8359, device='cuda:0') PRULE tensor(0.2944, device='cuda:0')
# 34
# tensor(-211.0524, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7047, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8358, device='cuda:0') PRULE tensor(0.2987, device='cuda:0')
# 35
# tensor(-199.7752, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6672, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8358, device='cuda:0') PRULE tensor(0.2979, device='cuda:0')
# 36
# tensor(-214.4120, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7158, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8365, device='cuda:0') PRULE tensor(0.2956, device='cuda:0')
# 37
# tensor(-215.6010, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7198, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8371, device='cuda:0') PRULE tensor(0.2921, device='cuda:0')
# 38
# tensor(-212.7219, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7102, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8380, device='cuda:0') PRULE tensor(0.2914, device='cuda:0')
# 39
# tensor(-205.1037, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6849, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8386, device='cuda:0') PRULE tensor(0.2919, device='cuda:0')
# 40
# tensor(-207.5783, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6930, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8385, device='cuda:0') PRULE tensor(0.2919, device='cuda:0')
# 41
# tensor(-202.2736, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6755, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8380, device='cuda:0') PRULE tensor(0.2881, device='cuda:0')
# 42
# tensor(-205.5715, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6863, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8382, device='cuda:0') PRULE tensor(0.2853, device='cuda:0')
# 43
# tensor(-216.4444, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7226, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8385, device='cuda:0') PRULE tensor(0.2896, device='cuda:0')
# 44
# tensor(-216.7466, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7235, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8389, device='cuda:0') PRULE tensor(0.2920, device='cuda:0')
# 45
# tensor(-213.8007, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7139, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8390, device='cuda:0') PRULE tensor(0.2933, device='cuda:0')
# 46
# tensor(-211.5395, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7063, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8387, device='cuda:0') PRULE tensor(0.2939, device='cuda:0')
# 47
# tensor(-202.3114, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6755, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8388, device='cuda:0') PRULE tensor(0.2939, device='cuda:0')
# 48
# tensor(-208.0499, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6948, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8380, device='cuda:0') PRULE tensor(0.2950, device='cuda:0')
# 49
# tensor(-213.4100, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7125, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8381, device='cuda:0') PRULE tensor(0.2959, device='cuda:0')
# 50
# tensor(-203.9405, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6809, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8380, device='cuda:0') PRULE tensor(0.2962, device='cuda:0')
# 51
# tensor(-204.9415, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6845, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8380, device='cuda:0') PRULE tensor(0.2959, device='cuda:0')
# 52
# tensor(-199.0814, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6646, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8378, device='cuda:0') PRULE tensor(0.2956, device='cuda:0')
# 53
# tensor(-196.0044, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6545, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8379, device='cuda:0') PRULE tensor(0.2971, device='cuda:0')
# 54
# tensor(-206.0280, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6880, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8382, device='cuda:0') PRULE tensor(0.2969, device='cuda:0')
# 55
# tensor(-204.4924, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6828, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8381, device='cuda:0') PRULE tensor(0.2946, device='cuda:0')
# 56
# tensor(-206.1711, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6884, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8386, device='cuda:0') PRULE tensor(0.2935, device='cuda:0')
# 57
# tensor(-206.3034, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6890, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8390, device='cuda:0') PRULE tensor(0.2936, device='cuda:0')
# 58
# tensor(-204.7265, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6836, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8398, device='cuda:0') PRULE tensor(0.2900, device='cuda:0')
# 59
# tensor(-212.4950, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7094, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8400, device='cuda:0') PRULE tensor(0.2897, device='cuda:0')
# 60
# tensor(-203.4557, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6794, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8403, device='cuda:0') PRULE tensor(0.2905, device='cuda:0')
# 61
# tensor(-206.5589, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6897, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8397, device='cuda:0') PRULE tensor(0.2845, device='cuda:0')
# 62
# tensor(-206.8430, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6906, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8396, device='cuda:0') PRULE tensor(0.2819, device='cuda:0')
# 63
# tensor(-208.9302, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6975, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8397, device='cuda:0') PRULE tensor(0.2789, device='cuda:0')
# 64
# tensor(-208.8715, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6974, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8397, device='cuda:0') PRULE tensor(0.2768, device='cuda:0')
# 65
# tensor(-213.8132, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7140, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8400, device='cuda:0') PRULE tensor(0.2772, device='cuda:0')
# 66
# tensor(-201.2118, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6718, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8404, device='cuda:0') PRULE tensor(0.2797, device='cuda:0')
# 67
# tensor(-207.3176, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6923, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8404, device='cuda:0') PRULE tensor(0.2807, device='cuda:0')
# 68
# tensor(-200.0232, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6678, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8399, device='cuda:0') PRULE tensor(0.2787, device='cuda:0')
# 69
# tensor(-198.8711, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6642, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8397, device='cuda:0') PRULE tensor(0.2771, device='cuda:0')
# 70
# tensor(-210.9104, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7041, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8397, device='cuda:0') PRULE tensor(0.2792, device='cuda:0')
# 71
# tensor(-214.9199, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7175, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8395, device='cuda:0') PRULE tensor(0.2791, device='cuda:0')
# 72
# tensor(-216.4857, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7228, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8395, device='cuda:0') PRULE tensor(0.2789, device='cuda:0')
# 73
# tensor(-208.9902, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6978, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8399, device='cuda:0') PRULE tensor(0.2769, device='cuda:0')
# 74
# tensor(-206.7679, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6904, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8404, device='cuda:0') PRULE tensor(0.2780, device='cuda:0')
# 75
# tensor(-217.4936, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7262, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8407, device='cuda:0') PRULE tensor(0.2762, device='cuda:0')
# 0
# tensor(-224.8784, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7507, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8410, device='cuda:0') PRULE tensor(0.2750, device='cuda:0')
# 1
# tensor(-199.2557, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6652, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8409, device='cuda:0') PRULE tensor(0.2759, device='cuda:0')
# 2
# tensor(-210.9948, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7046, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8404, device='cuda:0') PRULE tensor(0.2737, device='cuda:0')
# 3
# tensor(-199.5755, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6664, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8404, device='cuda:0') PRULE tensor(0.2718, device='cuda:0')
# 4
# tensor(-218.9888, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7310, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8403, device='cuda:0') PRULE tensor(0.2708, device='cuda:0')
# 5
# tensor(-214.1022, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7147, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8403, device='cuda:0') PRULE tensor(0.2721, device='cuda:0')
# 6
# tensor(-206.5936, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6898, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8405, device='cuda:0') PRULE tensor(0.2730, device='cuda:0')
# 7
# tensor(-207.4983, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6927, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8402, device='cuda:0') PRULE tensor(0.2745, device='cuda:0')
# 8
# tensor(-213.6764, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7134, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8404, device='cuda:0') PRULE tensor(0.2764, device='cuda:0')
# 9
# tensor(-206.3752, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6891, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8403, device='cuda:0') PRULE tensor(0.2785, device='cuda:0')
# 10
# tensor(-208.7131, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6969, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8412, device='cuda:0') PRULE tensor(0.2812, device='cuda:0')
# 11
# tensor(-198.1944, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6618, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8412, device='cuda:0') PRULE tensor(0.2831, device='cuda:0')
# 12
# tensor(-204.3958, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6824, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8407, device='cuda:0') PRULE tensor(0.2878, device='cuda:0')
# 13
# tensor(-215.4833, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7195, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8405, device='cuda:0') PRULE tensor(0.2911, device='cuda:0')
# 14
# tensor(-210.1895, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7018, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8403, device='cuda:0') PRULE tensor(0.2937, device='cuda:0')
# 15
# tensor(-202.9007, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6775, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8402, device='cuda:0') PRULE tensor(0.3008, device='cuda:0')
# 16
# tensor(-205.0141, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6844, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8405, device='cuda:0') PRULE tensor(0.2948, device='cuda:0')
# 17
# tensor(-213.3023, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7122, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8405, device='cuda:0') PRULE tensor(0.2952, device='cuda:0')
# 18
# tensor(-211.4658, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7061, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8409, device='cuda:0') PRULE tensor(0.2944, device='cuda:0')
# 19
# tensor(-217.8905, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7276, device='cuda:0', grad_fn=<MseLossBackward>)
# ...
# 15
# tensor(-214.4300, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7158, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8505, device='cuda:0') PRULE tensor(0.2937, device='cuda:0')
# 16
# tensor(-211.0932, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7046, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8504, device='cuda:0') PRULE tensor(0.2906, device='cuda:0')
# 17
# tensor(-208.9342, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6975, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8505, device='cuda:0') PRULE tensor(0.2902, device='cuda:0')
# 18
# tensor(-187.1363, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6248, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8496, device='cuda:0') PRULE tensor(0.2923, device='cuda:0')
# 19
# tensor(-212.2466, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7086, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8489, device='cuda:0') PRULE tensor(0.2914, device='cuda:0')
# 20
# tensor(-212.7998, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7104, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8487, device='cuda:0') PRULE tensor(0.2899, device='cuda:0')
# 21
# tensor(-215.0148, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7178, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8493, device='cuda:0') PRULE tensor(0.2930, device='cuda:0')
# 22
# tensor(-202.7543, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6769, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8501, device='cuda:0') PRULE tensor(0.2956, device='cuda:0')
# 23
# tensor(-216.8470, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7239, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8505, device='cuda:0') PRULE tensor(0.2915, device='cuda:0')
# 24
# tensor(-201.4897, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6726, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8504, device='cuda:0') PRULE tensor(0.2913, device='cuda:0')
# 25
# tensor(-210.4233, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7025, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8505, device='cuda:0') PRULE tensor(0.2938, device='cuda:0')
# 26
# tensor(-205.8811, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6874, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8506, device='cuda:0') PRULE tensor(0.2956, device='cuda:0')
# 27
# tensor(-213.0548, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7113, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8503, device='cuda:0') PRULE tensor(0.2956, device='cuda:0')
# 28
# tensor(-212.1268, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7083, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8507, device='cuda:0') PRULE tensor(0.2954, device='cuda:0')
# 29
# tensor(-211.5200, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7062, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8505, device='cuda:0') PRULE tensor(0.2939, device='cuda:0')
# 30
# tensor(-206.0870, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6881, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8507, device='cuda:0') PRULE tensor(0.2926, device='cuda:0')
# 31
# tensor(-209.6725, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7000, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8500, device='cuda:0') PRULE tensor(0.2968, device='cuda:0')
# 32
# tensor(-208.1935, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6949, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8481, device='cuda:0') PRULE tensor(0.2921, device='cuda:0')
# 33
# tensor(-211.7216, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7067, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8480, device='cuda:0') PRULE tensor(0.2904, device='cuda:0')
# 34
# tensor(-210.3915, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7023, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8480, device='cuda:0') PRULE tensor(0.2910, device='cuda:0')
# 35
# tensor(-214.2196, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7152, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8481, device='cuda:0') PRULE tensor(0.2946, device='cuda:0')
# 36
# tensor(-207.0434, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6912, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8498, device='cuda:0') PRULE tensor(0.2997, device='cuda:0')
# 37
# tensor(-212.7713, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7104, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8503, device='cuda:0') PRULE tensor(0.2996, device='cuda:0')
# 38
# tensor(-219.9151, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7341, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8512, device='cuda:0') PRULE tensor(0.3020, device='cuda:0')
# 39
# tensor(-212.7227, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7102, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8506, device='cuda:0') PRULE tensor(0.3029, device='cuda:0')
# 40
# tensor(-215.1496, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7183, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8500, device='cuda:0') PRULE tensor(0.3034, device='cuda:0')
# 41
# tensor(-204.4041, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6824, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8505, device='cuda:0') PRULE tensor(0.3018, device='cuda:0')
# 42
# tensor(-210.3845, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7024, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8511, device='cuda:0') PRULE tensor(0.2979, device='cuda:0')
# 43
# tensor(-209.5332, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6994, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8501, device='cuda:0') PRULE tensor(0.2978, device='cuda:0')
# 44
# tensor(-218.1208, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7281, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8496, device='cuda:0') PRULE tensor(0.2986, device='cuda:0')
# 45
# tensor(-216.6230, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7232, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8488, device='cuda:0') PRULE tensor(0.2953, device='cuda:0')
# 46
# tensor(-206.0237, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6878, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8488, device='cuda:0') PRULE tensor(0.2959, device='cuda:0')
# 47
# tensor(-200.9100, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6708, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8494, device='cuda:0') PRULE tensor(0.2996, device='cuda:0')
# 48
# tensor(-214.3695, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7157, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8508, device='cuda:0') PRULE tensor(0.2967, device='cuda:0')
# 49
# tensor(-209.0079, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6977, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8520, device='cuda:0') PRULE tensor(0.2958, device='cuda:0')
# 50
# tensor(-217.7746, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7271, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8496, device='cuda:0') PRULE tensor(0.2991, device='cuda:0')
# 51
# tensor(-217.2107, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7250, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8479, device='cuda:0') PRULE tensor(0.3024, device='cuda:0')
# 52
# tensor(-222.2983, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7422, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8479, device='cuda:0') PRULE tensor(0.3030, device='cuda:0')
# 53
# tensor(-204.1279, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6816, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8495, device='cuda:0') PRULE tensor(0.3040, device='cuda:0')
# 54
# tensor(-211.8836, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7073, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8520, device='cuda:0') PRULE tensor(0.3051, device='cuda:0')
# 55
# tensor(-216.1981, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7218, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8520, device='cuda:0') PRULE tensor(0.3027, device='cuda:0')
# 56
# tensor(-211.3969, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7058, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8508, device='cuda:0') PRULE tensor(0.3015, device='cuda:0')
# 57
# tensor(-202.4267, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6758, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8507, device='cuda:0') PRULE tensor(0.3068, device='cuda:0')
# 58
# tensor(-210.3457, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7022, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8491, device='cuda:0') PRULE tensor(0.3101, device='cuda:0')
# 59
# tensor(-221.4449, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7393, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8475, device='cuda:0') PRULE tensor(0.3096, device='cuda:0')
# 60
# tensor(-212.7635, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7103, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8473, device='cuda:0') PRULE tensor(0.3114, device='cuda:0')
# 61
# tensor(-214.7726, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7170, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8492, device='cuda:0') PRULE tensor(0.3130, device='cuda:0')
# 62
# tensor(-222.8277, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7439, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8511, device='cuda:0') PRULE tensor(0.3174, device='cuda:0')
# 63
# tensor(-220.2870, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7354, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8518, device='cuda:0') PRULE tensor(0.3213, device='cuda:0')
# 64
# tensor(-208.9093, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6974, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8515, device='cuda:0') PRULE tensor(0.3227, device='cuda:0')
# 65
# tensor(-221.2971, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7387, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8510, device='cuda:0') PRULE tensor(0.3284, device='cuda:0')
# 66
# tensor(-212.6306, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7100, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8512, device='cuda:0') PRULE tensor(0.3258, device='cuda:0')
# 67
# tensor(-221.2558, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7386, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8512, device='cuda:0') PRULE tensor(0.3210, device='cuda:0')
# 68
# tensor(-223.3557, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7456, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8518, device='cuda:0') PRULE tensor(0.3173, device='cuda:0')
# 69
# tensor(-206.0126, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6877, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8523, device='cuda:0') PRULE tensor(0.3112, device='cuda:0')
# 70
# tensor(-212.7786, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7104, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8502, device='cuda:0') PRULE tensor(0.3161, device='cuda:0')
# 71
# tensor(-214.3162, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7154, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8490, device='cuda:0') PRULE tensor(0.3136, device='cuda:0')
# 72
# tensor(-186.9196, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6243, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8493, device='cuda:0') PRULE tensor(0.3134, device='cuda:0')
# 73
# tensor(-214.1914, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7152, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8501, device='cuda:0') PRULE tensor(0.3102, device='cuda:0')
# 74
# tensor(-210.6321, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7032, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8515, device='cuda:0') PRULE tensor(0.3072, device='cuda:0')
# 75
# tensor(-204.1589, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6817, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8526, device='cuda:0') PRULE tensor(0.3017, device='cuda:0')
# 0
# tensor(-199.3525, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6656, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8517, device='cuda:0') PRULE tensor(0.2982, device='cuda:0')
# 1
# tensor(-208.0910, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6946, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8517, device='cuda:0') PRULE tensor(0.2965, device='cuda:0')
# 2
# tensor(-213.8456, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7138, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8520, device='cuda:0') PRULE tensor(0.2951, device='cuda:0')
# 3
# tensor(-212.5552, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7096, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8518, device='cuda:0') PRULE tensor(0.2939, device='cuda:0')
# 4
# tensor(-207.9211, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6941, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8525, device='cuda:0') PRULE tensor(0.2921, device='cuda:0')
# 5
# tensor(-219.5861, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7330, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8526, device='cuda:0') PRULE tensor(0.2923, device='cuda:0')
# 6
# tensor(-215.1557, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7182, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8523, device='cuda:0') PRULE tensor(0.2931, device='cuda:0')
# 7
# tensor(-206.7972, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6904, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8521, device='cuda:0') PRULE tensor(0.2887, device='cuda:0')
# 8
# tensor(-204.8967, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6841, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8521, device='cuda:0') PRULE tensor(0.2876, device='cuda:0')
# 9
# tensor(-212.2048, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7084, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8521, device='cuda:0') PRULE tensor(0.2909, device='cuda:0')
# 10
# tensor(-209.3697, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6990, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8523, device='cuda:0') PRULE tensor(0.2894, device='cuda:0')
# 11
# tensor(-214.8019, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.7170, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8521, device='cuda:0') PRULE tensor(0.2885, device='cuda:0')
# 12
# tensor(-205.9681, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(0.6876, device='cuda:0', grad_fn=<MseLossBackward>)
# ACC tensor(0.8518, device='cuda:0') PRULE tensor(0.2876, device='cuda:0')
# 13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-553e4fe7468d> in <module>()
#     103           ypred_ADV = model_ADV(ypred2)
#     104           lossX =criterion_ADV(ypred_ADV,S)
# --> 105           optimizer_ADV.step()
#     106         #Yhat_count =  Variable(torch.FloatTensor(ypred_var.data.numpy().T.repeat(nb_a,1).T))
#     107         #MSEcount = (Yhat_count-ypredcontworld).pow(2).sum()
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      92             denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      93         else:
# ---> 94             denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      95
#      96         step_size = lr / bias_correction1
#
# KeyboardInterrupt:

# %%
# Out:
# tensor([[-4.4928,  6.4100,  0.4568,  0.3463, -0.6158],
#         [-6.5117,  0.7561, -3.5439, -0.9248, -5.9962],
#         [-2.1233, -1.4062,  0.4550, -0.3655, -5.0423],
#         ...,
#         [-0.8465,  3.3012, -4.0236, -3.1975, -0.0640],
#         [-6.7243, -0.5177, -1.8809, -1.2876, -2.2849],
#         [ 0.5550, -0.4949,  5.2409,  1.7638,  2.3707]], device='cuda:0',
#        grad_fn=<AddBackward0>)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit (S, [0, 1, 2])

# %%
S
# Out:
# tensor([[ 0.4173],
#         [-0.6840],
#         [-0.8557],
#         ...,
#         [-1.7567],
#         [-3.0534],
#         [ 3.2146]], device='cuda:0', grad_fn=<AddBackward0>)

# %%
Ypred
# Out:
# tensor([[ True],
#         [False],
#         [False],
#         ...,
#         [False],
#         [ True],
#         [False]], device='cuda:0')

# %%
# Out:
# tensor(0.2951, device='cuda:0')

# %%
def p_rule(y_pred, z_values, threshold=0.5):
    
    y_z_1 = y_pred[z_values == 1] > threshold if threshold else y_pred[z_values == 1]
    y_z_0 = y_pred[z_values == 0] > threshold if threshold else y_pred[z_values == 0]
    odds = y_z_1.mean() / y_z_0.mean()
    return np.min([odds, 1/odds]) * 100

# %%
max(Ypred[H].float().mean()/Ypred[F].float().mean(), Ypred[F].float().mean()/Ypred[H].float().mean())
# Out:
# tensor(3.3888, device='cuda:0')

# %%
(Ypred==y_trainCUDA).shape
# Out:
# torch.Size([39072, 1])

# %%
(Ypred==)
# Out:
# tensor([[True],
#         [True],
#         [True],
#         ...,
#         [True],
#         [True],
#         [True]], device='cuda:0')

# %%
Ypred
# Out:
# tensor([[0.9672],
#         [0.9543],
#         [0.9609],
#         ...,
#         [0.9531],
#         [0.9504],
#         [0.9477]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
X_trainCUDA.view(-1, 53)
# Out:
# tensor([[0.0948, 0.8000, 0.1434,  ..., 0.0000, 1.0000, 0.0000],
#         [0.0983, 0.6000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.3557, 0.8000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.1180, 0.6000, 0.0000,  ..., 1.0000, 0.0000, 0.0000],
#         [0.0704, 0.8000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.1481, 0.5333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')

# %%
x_var.repeat(nb_a,1).view(-1, 53).shape
# Out:
# torch.Size([102400, 53])

# %%
x_varNC.repeat(nb_a,1).view(-1, 43).shape
# Out:
# torch.Size([400000, 43])

# %%
y_var.repeat(nb_a,1).view(-1, 1).shape
# Out:
# torch.Size([102400, 1])

# %%
s_var.repeat(nb_a,1).view(-1, 1).shape
# Out:
# torch.Size([102400, 1])

# %%
nb_a
# Out:
# 200

# %%
from sklearn.utils import shuffle
from torch.autograd import Variable
import math

batch_size = 512
num_epochs = 2000
learning_rate = 0.0001
batch_no = len(X_train) // batch_size
X_train_inv = recon_X_batch.data.numpy()
Y_train_inv = recon_Y_batch.data.numpy()
Y_train_inv = (Y_train_inv>0.5)*1
criterionMSE = nn.MSELoss()

def sigmoid(x):
  output = [1 / (1 + math.exp(-x)) for x in x]
  return output

class encodeder(nn.Module):
    def __init__(self):
        super(encodeder, self).__init__()
        self.fc1 = nn.Linear(33, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
    def forward(self, x):
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        return x

class NN_y(nn.Module):
    def __init__(self):
        super(NN_y, self).__init__()
        self.fc1_y = nn.Linear(16, 8)
        self.fc2_y = nn.Linear(8, 1)

    def forward(self, x):
        x = self.fc1_y(x)
        x = torch.relu(x)
        x = self.fc2_y(x)
        return x

class NN_s(nn.Module):
    def __init__(self):
        super(NN_s, self).__init__()
        self.fc1_s = nn.Linear(16, 8)
        self.fc2_s = nn.Linear(8, 1)

    def forward(self, x):
        x = self.fc1_s(x)
        x = torch.relu(x)
        x = self.fc2_s(x)
        return x
criterion = torch.nn.BCEWithLogitsLoss(reduction='mean')

m_encodeder = encodeder()
m_NN_y = NN_y()
m_NN_s = NN_s()

optimizer_enc = torch.optim.Adam(m_encodeder.parameters(), lr=learning_rate)
optimizer_y = torch.optim.Adam(m_NN_y.parameters(), lr=learning_rate)
optimizer_s = torch.optim.Adam(m_NN_s.parameters(), lr=learning_rate)

lambda_ADV = 10
for epoch in range(num_epochs):
    x_train, x_trainNC, ytrain, senstrain = shuffle(X_train, XNC_train , np.expand_dims(y_train,axis = 1), S_train)
    # Mini batch learning
    for i in range(batch_no):
        start = i * batch_size
        end = start + batch_size
        x_var = Variable(torch.FloatTensor(x_train[start:end]))
        x_trainNC = Variable(torch.FloatTensor(x_trainNC[start:end]))
        y_var = Variable(torch.FloatTensor(ytrain[start:end]))
        s_var = Variable(torch.FloatTensor(sens_train[start:end]))

        optimizer.zero_grad()
        for k in range(50):
          optimizer_y.zero_grad()
          optimizer_s.zero_grad() 
          Z= m_encodeder(x_var)
          Spred_var = m_NN_y(Z)
          Ypred_var = m_NN_s(Z)
          lossS =criterion(Spred_var, s_var)
          lossY =criterion(Ypred_var, y_var)
          lossS.backward(retain_graph=True)
          lossY.backward(retain_graph=True)
          optimizer_y.step()
          optimizer_s.step()

        Spred_var = m_NN_y(Z)
        Ypred_var = m_NN_s(Z)
        lossS =criterion(Spred_var, s_var)
        lossY =criterion(Ypred_var, y_var)

        loss = - lambda_ADV*lossS + lossY 

        loss.backward()
        optimizer.step()
    if epoch % 50 == 0:
      print('epoch', epoch,'loss',loss.data.numpy(),'lossS',lossS.data.numpy(),'lossY',lossY.data.numpy())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0f0e620faeb7> in <module>()
#       1 from sklearn.utils import shuffle
# ----> 2 from torch.autograd import Variable
#       3 import math
#       4
#       5 batch_size = 512
#
# /usr/local/lib/python3.6/dist-packages/torch/__init__.py in <module>()
#     314 import torch.hub
#     315 import torch.random
# --> 316 import torch.distributions
#     317 import torch.testing
#     318 import torch.backends.cuda
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in _compile_bytecode(data, name, bytecode_path, source_path)
#
# KeyboardInterrupt:

# %%
y_pred = clf.predict(X_test).squeeze(1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
H = 15
H2 = 15


class Net_HGR(nn.Module):
    def __init__(self):
        super(Net_HGR, self).__init__()
        self.fc1 = nn.Linear(1, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, H2)
        self.fc4 = nn.Linear(H2, 1)
        self.bn1 = nn.BatchNorm1d(1)

    def forward(self, x):
        h1 = torch.tanh(self.fc1(x))
        h2 = torch.relu(self.fc2(h1))
        h3 = torch.tanh(self.fc3(h2))
        h4 = self.fc4(h3)
        return h4    


class Net2_HGR(nn.Module):
    def __init__(self):
        super(Net2_HGR, self).__init__()
        self.fc1 = nn.Linear(1, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, H2)
        self.fc4 = nn.Linear(H2, 1)
        self.bn1 = nn.BatchNorm1d(1)

    def forward(self, x):
        h1 = torch.tanh(self.fc1(x))
        h2 = torch.relu(self.fc2(h1))
        h3 = torch.tanh(self.fc3(h2))
        h4 = self.fc4(h3)
        return h4    


model_Net_F = Net_HGR()
model_Net_G = Net2_HGR()


class HGR_NN(nn.Module):
    
    def __init__(self,model_F,model_G):
        super(HGR_NN, self).__init__()
        self.mF = model_Net_F
        self.mG = model_Net_G
        self.optimizer_F = torch.optim.Adam(self.mF.parameters(), lr=0.001)
        self.optimizer_G = torch.optim.Adam(self.mG.parameters(), lr=0.001)

    def forward(self, yhat, y2_var,nb):
      
        for j in range(nb) :
            #ret = torch.mean(pred_xy) - torch.log(torch.mean(torch.exp(pred_x_y)))
            #ret = torch.mean(pred_xy) - torch.mean(pred_x_y) - 0.25*torch.mean(torch.pow(pred_x_y,2))

            yhat2  =yhat.data.numpy()
            y2_var2=y2_var.data.numpy()
        
            yhat2_PT  = torch.from_numpy(yhat2).type(torch.FloatTensor)
            y2_var_PT = torch.from_numpy(y2_var2).type(torch.FloatTensor)

            pred_F  = self.mF(yhat2_PT)
            pred_G  = self.mG(y2_var_PT)

            pred_F_norm = (pred_F-torch.mean(pred_F))/torch.std(pred_F)
            pred_G_norm = (pred_G-torch.mean(pred_G))/torch.std(pred_G)

            #epsilon=0.0000000000000000001
            epsilon=0.0001 
            pred_F_norm = (pred_F-torch.mean(pred_F))/torch.sqrt((torch.std(pred_F).pow(2)+epsilon))
            pred_G_norm = (pred_G-torch.mean(pred_G))/torch.sqrt((torch.std(pred_G).pow(2)+epsilon))
            pred_F_norm[torch.isnan(pred_F_norm )] = 0
            pred_G_norm[torch.isnan(pred_G_norm )] = 0

            ret = torch.mean(pred_F_norm*pred_G_norm)
            loss = - ret  # maximize
            self.mF.zero_grad()
            self.mG.zero_grad()
            loss.backward()
            #print(loss)
            self.optimizer_F.step()
            self.optimizer_G.step()

        return ret.data.numpy()

# %%
y_pred = pd.Series(clf.predict(X_test).squeeze(1))

# %%
# lambda = 0
HGR_NNP = HGR_NN(Net_HGR(),Net2_HGR())
print("HGR NN Test",HGR_NNP(torch.FloatTensor(y_pred).unsqueeze(1) , torch.FloatTensor(Z_test).unsqueeze(1),10000))
print(f"Accuracy: {np.mean((y_test-y_pred)**2)}%")
# Out:
# HGR NN Test 0.2241652
# Accuracy: 0.9594637821755506%

# %%
from sklearn.utils import shuffle
from torch.autograd import Variable
import math

batch_size = 512
num_epochs = 2000
learning_rate = 0.0001
batch_no = len(X_train) // batch_size
X_train_inv = recon_X_batch.data.numpy()
Y_train_inv = recon_Y_batch.data.numpy()
Y_train_inv = (Y_train_inv>0.5)*1
criterionMSE = nn.MSELoss()

def sigmoid(x):
  output = [1 / (1 + math.exp(-x)) for x in x]
  return output

class encodeder(nn.Module):
    def __init__(self):
        super(encodeder, self).__init__()
        self.fc1 = nn.Linear(33, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
    def forward(self, x):
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.fc2(x)
        x = torch.relu(x)
        x = self.fc3(x)
        return x

class NN_y(nn.Module):
    def __init__(self):
        super(NN_y, self).__init__()
        self.fc1_y = nn.Linear(16, 8)
        self.fc2_y = nn.Linear(8, 1)

    def forward(self, x):
        x = self.fc1_y(x)
        x = torch.relu(x)
        x = self.fc2_y(x)
        return x

class NN_s(nn.Module):
    def __init__(self):
        super(NN_s, self).__init__()
        self.fc1_s = nn.Linear(16, 8)
        self.fc2_s = nn.Linear(8, 1)

    def forward(self, x):
        x = self.fc1_s(x)
        x = torch.relu(x)
        x = self.fc2_s(x)
        return x
criterion = torch.nn.BCEWithLogitsLoss(reduction='mean')

m_encodeder = encodeder()
m_NN_y = NN_y()
m_NN_s = NN_s()

optimizer_enc = torch.optim.Adam(m_encodeder.parameters(), lr=learning_rate)
optimizer_y = torch.optim.Adam(m_NN_y.parameters(), lr=learning_rate)
optimizer_s = torch.optim.Adam(m_NN_s.parameters(), lr=learning_rate)

lambda_ADV = 10
for epoch in range(num_epochs):
    x_train, ytrain, sens_train = shuffle(X_train, np.expand_dims(y_train,axis = 1), np.expand_dims(Z_train,axis = 1))
    # Mini batch learning
    for i in range(batch_no):
        start = i * batch_size
        end = start + batch_size
        x_var = Variable(torch.FloatTensor(x_train[start:end]))
        y_var = Variable(torch.FloatTensor(ytrain[start:end]))
        s_var = Variable(torch.FloatTensor(sens_train[start:end]))

        optimizer.zero_grad()
        for k in range(50):
          optimizer_y.zero_grad()
          optimizer_s.zero_grad() 
          Z= m_encodeder(x_var)
          Spred_var = m_NN_y(Z)
          Ypred_var = m_NN_s(Z)
          lossS =criterion(Spred_var, s_var)
          lossY =criterion(Ypred_var, y_var)
          lossS.backward(retain_graph=True)
          lossY.backward(retain_graph=True)
          optimizer_y.step()
          optimizer_s.step()

        Spred_var = m_NN_y(Z)
        Ypred_var = m_NN_s(Z)
        lossS =criterion(Spred_var, s_var)
        lossY =criterion(Ypred_var, y_var)

        loss = - lambda_ADV*lossS + lossY 

        loss.backward()
        optimizer.step()
    if epoch % 50 == 0:
      print('epoch', epoch,'loss',loss.data.numpy(),'lossS',lossS.data.numpy(),'lossY',lossY.data.numpy())# HIDE
def plot_distributions(y, Z, iteration=None, val_metrics=None, p_rules=None, fname=None):
    fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharey=True)
    legend={'race': ['black','white'],
            'sex': ['female','male']}
    for idx, attr in enumerate(Z.columns):
        for attr_val in [0, 1]:
            ax = sns.distplot(y[Z[attr] == attr_val], hist=False, 
                              kde_kws={'shade': True,},
                              label='{}'.format(legend[attr][attr_val]), 
                              ax=axes[idx])
        ax.set_xlim(0,1)
        ax.set_ylim(0,7)
        ax.set_yticks([])
        ax.set_title("sensitive attibute: {}".format(attr))
        if idx == 0:
            ax.set_ylabel('prediction distribution')
        ax.set_xlabel(r'$P({{income>50K}}|z_{{{}}})$'.format(attr))
    if iteration:
        fig.text(1.0, 0.9, f"Training iteration #{iteration}", fontsize='16')
    if val_metrics is not None:
        fig.text(1.0, 0.65, '\n'.join(["Prediction performance:",
                                       f"- ROC AUC: {val_metrics['ROC AUC']:.2f}",
                                       f"- Accuracy: {val_metrics['Accuracy']:.1f}"]),
                 fontsize='16')
    if p_rules is not None:
        fig.text(1.0, 0.4, '\n'.join(["Satisfied p%-rules:"] +
                                     [f"- {attr}: {p_rules[attr]:.0f}%-rule" 
                                      for attr in p_rules.keys()]), 
                 fontsize='16')
    fig.tight_layout()
    if fname is not None:
        plt.savefig(fname, bbox_inches='tight')
    return fig

# %%
fig = plot_distributions(y_pred, Z_test, fname='biased_training.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e1adedb05e75> in <module>()
# ----> 1 fig = plot_distributions(y_pred, Z_test, fname='biased_training.png')
#
# NameError: name 'y_pred' is not defined

# %%
def p_rule(y_pred, z_values, threshold=0.5):
    y_z_1 = y_pred[z_values == 1] > threshold if threshold else y_pred[z_values == 1]
    y_z_0 = y_pred[z_values == 0] > threshold if threshold else y_pred[z_values == 0]
    odds = y_z_1.mean() / y_z_0.mean()
    return np.min([odds, 1/odds]) * 100

# %%
print("The classifier satisfies the following %p-rules:")
print(f"\tgiven attribute race; {p_rule(y_pred, Z_test['race']):.0f}%-rule")
print(f"\tgiven attribute sex;  {p_rule(y_pred, Z_test['sex']):.0f}%-rule")
# Out:
# The classifier satisfies the following %p-rules:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-302f85e3d118> in <module>()
#       1 print("The classifier satisfies the following %p-rules:")
# ----> 2 print(f"\tgiven attribute race; {p_rule(y_pred, Z_test['race']):.0f}%-rule")
#       3 print(f"\tgiven attribute sex;  {p_rule(y_pred, Z_test['sex']):.0f}%-rule")
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
